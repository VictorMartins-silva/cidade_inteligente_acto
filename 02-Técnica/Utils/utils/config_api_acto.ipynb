# %%
# Tokens dos ambientes de Gestão do Acto

TOKEN_SANTOS = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....mPM5T3q4ytYLNr8iy7kgG5HEOKfOBvEDSXWwlKZ9gS0"

TOKEN_SANTOS_OBRAS = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....DRZy6ivkjFKO_Y4mdEKdWVVZtPrBsRdbNGDcKqwLJ5w"

TOKEN_OSASCO = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....LgAtRdy2IkfjN6ZkrHFO21fFHJs2i2QRkownnj2JPxk"

TOKEN_MAUA = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....185cLcfnbfQc7qegPfOnp8b5I1n3lHJvuSlh3lqIViE"
# Out:
# StatementMeta(, a046f1f7-e2c6-4f69-8be5-a25660a70d60, 3, Finished, Available, Finished, True)
