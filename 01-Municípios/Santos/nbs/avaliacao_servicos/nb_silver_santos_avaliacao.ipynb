# %%
# %run ./config_api_acto
# Out:
# StatementMeta(, ecf76b19-107d-464f-b57a-ae32a332b43b, 13, Finished, Available, Finished, True)

# %%
# %run ./nb_utils_ingest_acto_gestao
# Out:
# StatementMeta(, ecf76b19-107d-464f-b57a-ae32a332b43b, 14, Finished, Available, Finished, True)

# %%
TOKEN = TOKEN_SANTOS
# Out:
# StatementMeta(, ecf76b19-107d-464f-b57a-ae32a332b43b, 15, Finished, Available, Finished, False)

# %%
path_payload_json = "/lakehouse/default/Files/acto_gestao_api_payload/payload_santos_avaliacao.json"

df_solicitacoes, df_etapas = extrair_tabela_acto_gestao(path_payload_json, TOKEN)

df_solicitacoes.to_parquet("/lakehouse/default/Files/silver/avaliacoes_servico/silver_avaliacoes_servico.parquet", index=False)
print("Arquivo .parquet salvo com sucesso")
# Out:
# StatementMeta(, ecf76b19-107d-464f-b57a-ae32a332b43b, 16, Finished, Available, Finished, False)
# Solicitações: 12996
# OSs tempo/etapa: 12996
