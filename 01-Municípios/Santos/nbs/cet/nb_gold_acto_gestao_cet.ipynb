# %%
# %run ./nb_utils_api_acto_gestao
# Out:
# StatementMeta(, ff95625b-9e26-4562-bc30-757c999884d9, 6, Finished, Available, Finished, True)

# %%
import numpy as np

ARQUIVO_AUX = "abfss://96fe5a53-3a22-4443-8d0a-e2f6d61a2690@onelake.dfs.fabric.microsoft.com/0f8d9b0e-86cc-4454-9772-4ab92eb4db2a/Files/acto/tb_aux.xlsx"


def extrair_tabela_acto_gestao():

    df_etapas = obter_dados_etapa_atual(TOKEN, [
        8564, 10824, 10825, 11717, 11765, 
        11775, 12135, 12136, 12137, 12138, 
        12139, 12140, 12141, 12142, 12144, 
        12146, 12147, 12148, 12154, 12204, 
        12304, 12331, 12465, 12480
        ]
    )

    json_config = """{"nome":"cet_bi","solicitacoes":[[{"codCatalogo":12480,"codConfigColCatalogo":0,"nomeServico":"Autorização temporária para carga e descarga em locais com restrições de estacionamento ou circulação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12480,"etapasDados":{"nomeServico":"12480","etapas":[38413,38433]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":2,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":3,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":4,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":5,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":6,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":25,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":777047,"linha":null,"largura":null,"codEtapa":38413,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_RESPONSAVEL_LEGAL","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":197,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":777090,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_INICIO_CARGA_DESCARGA","tit":"Data de início:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":210,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":776960,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_TERMINO_CARGA_DESCARGA","tit":"Data de término:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":212,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":795150,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_HORARIO_TERMINO","tit":"Horario de término:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":224,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":777143,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_HORARIO_INICIO","tit":"Horário de início:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":226,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":777142,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_RESPONSAVEL_LEGAL","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":245,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":777091,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_RAZAO_SOCIAL_EMPRESA_CONSTRUTORA","tit":"Razão social:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":254,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":777097,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_SERVICO_EXECUTADO","tit":"Serviço a ser executado:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":257,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":804617,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_TIPO_SOLICITACAO","tit":"Tipo de solicitação:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":260,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":804616,"linha":null,"largura":null,"codEtapa":38433,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12465,"codConfigColCatalogo":0,"nomeServico":"Cadastro de caminhão para autorização em zona de restrição de circulação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12465,"etapasDados":{"nomeServico":"12465","etapas":[38233,38253]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":7,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":8,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":9,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":10,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":11,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":12,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":32,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":775556,"linha":null,"largura":null,"codEtapa":38233,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_AREA_EXECUTORA","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":90,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":775552,"linha":null,"largura":null,"codEtapa":38233,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_RESPONSAVEL_LEGAL","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":190,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":775691,"linha":null,"largura":null,"codEtapa":38253,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_RESPONSAVEL_LEGAL","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":234,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":775692,"linha":null,"largura":null,"codEtapa":38253,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_ZONA_RESTRICAO","tit":"Zona de Restrição de Circulação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":255,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":775641,"linha":null,"largura":null,"codEtapa":38253,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12331,"codConfigColCatalogo":0,"nomeServico":"Vaga temporária de carga e descarga para obras de construção civil","etapasSelecionadas":{"catalogo":[{"codCatalogo":12331,"etapasDados":{"nomeServico":"12331","etapas":[37396]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":13,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":14,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":15,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":16,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":17,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":18,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CNPJ_EMPRESA_CONSTRUTORA","tit":"CNPJ:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":34,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":755759,"linha":null,"largura":null,"codEtapa":37396,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":39,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":755787,"linha":null,"largura":null,"codEtapa":37396,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_RAZAO_SOCIAL_EMPRESA_CONSTRUTORA","tit":"Razão social:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":78,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":755757,"linha":null,"largura":null,"codEtapa":37396,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_AREA_EXECUTORA","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":86,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":755783,"linha":null,"largura":null,"codEtapa":37396,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12304,"codConfigColCatalogo":0,"nomeServico":"Transferência de permissão para exercer transporte de autolotação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12304,"etapasDados":{"nomeServico":"12304","etapas":[36522]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":19,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":20,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":21,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":22,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":23,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":24,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":43,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747335,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":44,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747149,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":49,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747319,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":52,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747160,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":96,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747320,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":120,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":747315,"linha":null,"largura":null,"codEtapa":36522,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12204,"codConfigColCatalogo":0,"nomeServico":"Credencial de Estacionamento para Idoso","etapasSelecionadas":{"catalogo":[{"codCatalogo":12204,"etapasDados":{"nomeServico":"12204","etapas":[37613,37615]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":26,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":27,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":28,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":29,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":30,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":31,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":55,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":757567,"linha":null,"largura":null,"codEtapa":37613,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":118,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":757718,"linha":null,"largura":null,"codEtapa":37615,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_ENCAMINHAMENTO","tit":"Encaminhamento da análise:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":135,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":757704,"linha":null,"largura":null,"codEtapa":37615,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":146,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE TÉCNICA","codFormularioCampo":757719,"linha":null,"largura":null,"codEtapa":37615,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12154,"codConfigColCatalogo":0,"nomeServico":"Fiscalização de veículo abandonado em via pública","etapasSelecionadas":{"catalogo":[{"codCatalogo":12154,"etapasDados":{"nomeServico":"12154","etapas":[36834,36833]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":33,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":35,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":36,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":37,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":38,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":40,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_ALTERACAO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":57,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752659,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":61,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752671,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":62,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752677,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_ALTERACAO","tit":"Nome do logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":81,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752656,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":84,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752672,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_ALTERACAO","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":85,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752657,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_OBSERVACOES_DESCRICAO","tit":"Observações:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":88,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752653,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_ALTERACAO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":97,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752655,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_AREA_RESPONSAVEL","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":101,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752668,"linha":null,"largura":null,"codEtapa":36833,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLACA","tit":"Placa do veículo:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":152,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DA ÁREA","codFormularioCampo":806036,"linha":null,"largura":null,"codEtapa":36834,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12148,"codConfigColCatalogo":0,"nomeServico":"Solicitação de substituição de veículo para autolotação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12148,"etapasDados":{"nomeServico":"12148","etapas":[37224]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":41,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":42,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":45,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":46,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":47,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":48,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":69,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752861,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":70,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752815,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":75,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752845,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":80,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752826,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":131,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752846,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":156,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":752841,"linha":null,"largura":null,"codEtapa":37224,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12147,"codConfigColCatalogo":0,"nomeServico":"Vistoria do veículo de autolotação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12147,"etapasDados":{"nomeServico":"12147","etapas":[36448]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":50,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":51,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":53,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":54,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":56,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":58,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":79,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":744987,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":82,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":745033,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":92,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":745017,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":95,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":744998,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":139,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":745018,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":165,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":745013,"linha":null,"largura":null,"codEtapa":36448,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12146,"codConfigColCatalogo":0,"nomeServico":"Renovação do registro de condutor para permissionário e auxiliar de transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12146,"etapasDados":{"nomeServico":"12146","etapas":[36506]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":59,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":60,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":63,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":64,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":65,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":66,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":93,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741860,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":94,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741814,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":104,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741844,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":105,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741825,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":150,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741845,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":177,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":741840,"linha":null,"largura":null,"codEtapa":36506,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12144,"codConfigColCatalogo":0,"nomeServico":"Autorização ou cancelamento para publicidade em táxi","etapasSelecionadas":{"catalogo":[{"codCatalogo":12144,"etapasDados":{"nomeServico":"12144","etapas":[36313]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":67,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":68,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":71,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":72,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":73,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":74,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":109,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728990,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":110,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728944,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":117,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728974,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":122,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728955,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":170,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728975,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":201,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":728970,"linha":null,"largura":null,"codEtapa":36313,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12142,"codConfigColCatalogo":0,"nomeServico":"Agendamento de escolta para carga superdimensionada","etapasSelecionadas":{"catalogo":[{"codCatalogo":12142,"etapasDados":{"nomeServico":"12142","etapas":[37274]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":76,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":77,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":83,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":87,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":89,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":91,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_RESPONSAVEL_LEGAL","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":119,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754254,"linha":null,"largura":null,"codEtapa":37274,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":123,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754317,"linha":null,"largura":null,"codEtapa":37274,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_RESPONSAVEL_LEGAL","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":167,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754255,"linha":null,"largura":null,"codEtapa":37274,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_AREA_EXECUTORA","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":191,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754313,"linha":null,"largura":null,"codEtapa":37274,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12141,"codConfigColCatalogo":0,"nomeServico":"Substituição temporária ou definitiva de veículo para transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12141,"etapasDados":{"nomeServico":"12141","etapas":[36573]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":98,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":99,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":100,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":102,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":103,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":106,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":126,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740008,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":127,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740054,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":136,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740038,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":141,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740019,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":189,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740039,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":219,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740034,"linha":null,"largura":null,"codEtapa":36573,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12140,"codConfigColCatalogo":0,"nomeServico":"Inscrição de condutor para motorista auxiliar do transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12140,"etapasDados":{"nomeServico":"12140","etapas":[36585]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":107,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":108,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":111,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":112,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":113,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":114,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":134,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740849,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":137,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740803,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":145,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740833,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":147,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740814,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":196,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740834,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":227,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":740829,"linha":null,"largura":null,"codEtapa":36585,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12139,"codConfigColCatalogo":0,"nomeServico":"Renovação de alvará de motorista auxiliar e motorista permissionário para autolotação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12139,"etapasDados":{"nomeServico":"12139","etapas":[37216]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":115,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":116,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":121,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":124,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":125,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":128,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":157,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":753728,"linha":null,"largura":null,"codEtapa":37216,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":158,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":753682,"linha":null,"largura":null,"codEtapa":37216,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":164,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":753712,"linha":null,"largura":null,"codEtapa":37216,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":166,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":753693,"linha":null,"largura":null,"codEtapa":37216,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":223,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":753713,"linha":null,"largura":null,"codEtapa":37216,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12138,"codConfigColCatalogo":0,"nomeServico":"Inscrição de condutor para motorista auxiliar de autolotação","etapasSelecionadas":{"catalogo":[{"codCatalogo":12138,"etapasDados":{"nomeServico":"12138","etapas":[37353]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":129,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":130,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":132,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":133,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":138,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":140,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":160,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":755005,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":161,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754973,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":172,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754957,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":173,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754938,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":222,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754958,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":252,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":754953,"linha":null,"largura":null,"codEtapa":37353,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12137,"codConfigColCatalogo":0,"nomeServico":"Autorização ou cancelamento para publicidade em transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12137,"etapasDados":{"nomeServico":"12137","etapas":[36539]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":142,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":143,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":144,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":148,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":149,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":151,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":176,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738536,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":178,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738602,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":184,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738586,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":186,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738567,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":238,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738587,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":267,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":738582,"linha":null,"largura":null,"codEtapa":36539,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12136,"codConfigColCatalogo":0,"nomeServico":"Vistoria do veículo de transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12136,"etapasDados":{"nomeServico":"12136","etapas":[36593]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":153,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":154,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":155,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":159,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":162,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":163,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":188,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739512,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":192,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739578,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":203,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739562,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":205,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739543,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":256,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739563,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":276,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":739558,"linha":null,"largura":null,"codEtapa":36593,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":12135,"codConfigColCatalogo":0,"nomeServico":"Transferência de permissão para exercer transporte escolar","etapasSelecionadas":{"catalogo":[{"codCatalogo":12135,"etapasDados":{"nomeServico":"12135","etapas":[36533]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":168,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":169,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":171,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":174,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":175,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":179,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":204,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737408,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":206,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737362,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":216,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737392,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":221,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737373,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":275,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737393,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":284,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":737388,"linha":null,"largura":null,"codEtapa":36533,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11775,"codConfigColCatalogo":0,"nomeServico":"Selo anual de autorização da atividade de táxi","etapasSelecionadas":{"catalogo":[{"codCatalogo":11775,"etapasDados":{"nomeServico":"11775","etapas":[36333]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":180,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":181,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":182,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":183,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":185,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":187,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":217,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729574,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":218,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729528,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":232,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729558,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":236,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729539,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":273,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729559,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":283,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729554,"linha":null,"largura":null,"codEtapa":36333,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11765,"codConfigColCatalogo":0,"nomeServico":"Renovação do registro do condutor auxiliar de táxi","etapasSelecionadas":{"catalogo":[{"codCatalogo":11765,"etapasDados":{"nomeServico":"11765","etapas":[36579]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":193,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":194,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":195,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":198,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":199,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":200,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":228,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":735875,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":229,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":758108,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":237,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":735859,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":240,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":735840,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":270,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":735860,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":280,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":735855,"linha":null,"largura":null,"codEtapa":36579,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11717,"codConfigColCatalogo":0,"nomeServico":"Declaração para isenção de IPI e ICMS para compra de táxi","etapasSelecionadas":{"catalogo":[{"codCatalogo":11717,"etapasDados":{"nomeServico":"11717","etapas":[36353]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":202,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":207,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":208,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":209,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":211,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":213,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":247,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729440,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":248,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729666,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":258,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729650,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":262,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729631,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":279,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729651,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":287,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":729646,"linha":null,"largura":null,"codEtapa":36353,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":10825,"codConfigColCatalogo":0,"nomeServico":"Substituição de veículo para exercer a atividade de táxi","etapasSelecionadas":{"catalogo":[{"codCatalogo":10825,"etapasDados":{"nomeServico":"10825","etapas":[33173]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":214,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":215,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":220,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":225,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":230,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":231,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":259,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":687468,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":261,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":688166,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO_AB","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":265,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":687440,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":268,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":687417,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":286,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":687441,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":289,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":687434,"linha":null,"largura":null,"codEtapa":33173,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":10824,"codConfigColCatalogo":0,"nomeServico":"Registro de condutor de táxi para auxiliar","etapasSelecionadas":{"catalogo":[{"codCatalogo":10824,"etapasDados":{"nomeServico":"10824","etapas":[29681]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":233,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":235,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":239,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":241,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":242,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":243,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":263,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":615951,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":264,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":686889,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":271,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":615955,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":272,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":615980,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":288,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":615954,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_DEPARTAMENTO","tit":"Área executora:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":290,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":615993,"linha":null,"largura":null,"codEtapa":29681,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":8564,"codConfigColCatalogo":0,"nomeServico":"Sinalização horizontal e ou vertical","etapasSelecionadas":{"catalogo":[{"codCatalogo":8564,"etapasDados":{"nomeServico":"8564","etapas":[36680]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":244,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":246,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":249,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":250,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":251,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":253,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_ALTERACAO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":266,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736545,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":269,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736558,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":274,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736568,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_OBSERVACOES_DESCRICAO","tit":"Descrição da solicitação:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":277,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736539,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_ALTERACAO","tit":"Nome do logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":278,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736542,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":281,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736559,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_ALTERACAO","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":282,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736543,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_ALTERACAO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":285,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":736541,"linha":null,"largura":null,"codEtapa":36680,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":13111,"codConfigColCatalogo":0,"nomeServico":"Cartão transporte para gratuidade de idosos","etapasSelecionadas":{"catalogo":[{"codCatalogo":13111,"etapasDados":{"nomeServico":"13111","etapas":[42953,42954]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":22,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":916099,"linha":null,"largura":null,"codEtapa":42953,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":2,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":3,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":4,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":5,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null}]],"ativo":true,"dataCriacao":"2026-01-09T18:19:11.441Z","dateDataAlteracao":"2026-04-08T14:52:23.338Z","filtros":[],"campos":[],"filtroData":false,"parametrosFiltrosData":[],"id":"6961469f9722d1a7bd2cb751","dateDataAlteracaoFormatada":"08/04/2026"}"""
    
    df_solicitacoes = fetch_tabela(json_config)

    # Lista de strings a procurar
    strings_procuradas = ["logradouro", "Logradouro", "Número"]

    # Encontrar colunas que contenham qualquer uma das strings
    colunas_encontradas = [col for col in df_solicitacoes.columns if any(s in col for s in strings_procuradas)]

    df_solicitacoes = df_solicitacoes.drop(columns=colunas_encontradas)

    return df_solicitacoes, df_etapas


def tratar_nome_coluna(df_solicitacoes_etapa):
    # TRATAMENTOS
    # renomear colunas para o padrão
    rename_map = {
        "seqFluxo": "os",
        "Serviço": "servico",
        "Status Fluxo": "status_fluxo",
        "Data Finalização": "data_finalizacao",
        "Data Criação": "data_solicitacao",
        "Solicitante": "solicitante",
        "Bairro": "bairro",
        "Canal": "canal",
        "Tipo de registro": "tipo_registro",
        "etapa": "etapa",
        "executor": "executor",
    }

    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map)

    # capitalizar o nome do serviço para manter padrão
    df_solicitacoes_etapa['servico'] = df_solicitacoes_etapa['servico'].str.capitalize()

    # transformar datas para o formato correto
    df_solicitacoes_etapa['data_solicitacao'] = pd.to_datetime(df_solicitacoes_etapa['data_solicitacao'], format="ISO8601")
    df_solicitacoes_etapa['data_finalizacao'] = pd.to_datetime(df_solicitacoes_etapa['data_finalizacao'], format="ISO8601")


    # TEMPORÁRIO: voltar para nome da tb_os_acto
    rename_map_bi_asis = {
        "os": "n_da_solicitacao",
        "status_fluxo": "status",
        "data_finalizacao": "data_de_finalizacao",
        "data_solicitacao": "data_de_solicitacao",
        "nome_servico": "nome_do_servico_avaliado",
        "tipo_manifestacao": "tipo_de_manifestacao",
        "bairro": "bairro_consolidado",
        "tipo_registro": "tipo_de_registro",
        "etapa": "etapa_atual",
        "executor": "executor_atual",
    }
    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map_bi_asis)

    return df_solicitacoes_etapa


def main():

    df_solicitacoes, df_etapas = extrair_tabela_acto_gestao()

    COLUNAS = [
        "Nº Solicitação", "Serviço", "Data Finalização", "Status Fluxo", "Bairro", "Solicitante", "Data Criação", "Canal", "CPF", "Nome"
    ]
    for c in COLUNAS:
        df_solicitacoes = aplicar_bfill(df_solicitacoes, c)

    df_solicitacoes_etapa = adicionar_etapa_atual_2(df_etapas, df_solicitacoes)

    df_solicitacoes_etapa = tratar_nome_coluna(df_solicitacoes_etapa)

    df_solicitacoes_etapa = harmonizar_nome_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = aplicar_merge_prazo_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_datas_prazos(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_base_final_solicitacoes(df_solicitacoes_etapa) 

    df_solicitacoes_etapa = remover_registros_teste(df_solicitacoes_etapa)

    # deixando igual ao tb_os_acto
    df = spark.sql("SELECT * FROM lh_cidade_inteligente_santos.tb_os_acto LIMIT 10").toPandas()
    df_solicitacoes_etapa = df_solicitacoes_etapa.reindex(columns=df.columns)

    return df_solicitacoes_etapa


df_solicitacoes_etapa = main()
# Out:
# StatementMeta(, ff95625b-9e26-4562-bc30-757c999884d9, 7, Finished, Available, Finished, False)
# Status: 200
# ✅ Linhas em pandas: 7633

# %%
sdf_solicitacoes_etapa = spark.createDataFrame(df_solicitacoes_etapa)
(
    sdf_solicitacoes_etapa
    .write.mode("overwrite")
    .format("delta")
    .option("overwriteSchema", "true")
    .saveAsTable("gold_cet_servicos")
)
# Out:
# StatementMeta(, ff95625b-9e26-4562-bc30-757c999884d9, 8, Finished, Available, Finished, True)
