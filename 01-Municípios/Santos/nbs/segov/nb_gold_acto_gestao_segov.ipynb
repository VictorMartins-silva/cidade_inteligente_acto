# %%
# %run ./nb_utils_api_acto_gestao
# Out:
# StatementMeta(, 326f6494-c688-48db-9ccc-8848a6dc26ae, 6, Finished, Available, Finished)

# %%
import numpy as np

ARQUIVO_AUX = "abfss://96fe5a53-3a22-4443-8d0a-e2f6d61a2690@onelake.dfs.fabric.microsoft.com/0f8d9b0e-86cc-4454-9772-4ab92eb4db2a/Files/acto/tb_aux.xlsx"


def extrair_tabela_acto_gestao():

    df_etapas = obter_dados_etapa_atual(TOKEN, [11737, 9019, 9007, 8994])
    
    json_config = """{"nome":"segov_bi","solicitacoes":[[{"codCatalogo":9019,"codConfigColCatalogo":0,"nomeServico":"Instalação, manutenção ou higienização de contentor","etapasSelecionadas":{"catalogo":[{"codCatalogo":9019,"etapasDados":{"nomeServico":"9019","etapas":[40660,40657]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":2,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":3,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":4,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":5,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":6,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":34,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":824472,"linha":null,"largura":null,"codEtapa":40657,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":93,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824581,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":104,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824563,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":136,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824578,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":147,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824562,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":152,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824579,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":171,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":824577,"linha":null,"largura":null,"codEtapa":40660,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":9007,"codConfigColCatalogo":0,"nomeServico":"Raspagem, capinação de vias e logradouros públicos","etapasSelecionadas":{"catalogo":[{"codCatalogo":9007,"etapasDados":{"nomeServico":"9007","etapas":[41355,41356]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":7,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":8,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":9,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":10,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":11,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":12,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":32,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":859394,"linha":null,"largura":null,"codEtapa":41355,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_INTERESSADO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":86,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859581,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":99,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859584,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_INTERESSADO","tit":"Nome do logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":138,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859578,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":142,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859583,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_INTERESSADO","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":146,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859579,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_INTERESSADO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":161,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":859577,"linha":null,"largura":null,"codEtapa":41356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":8994,"codConfigColCatalogo":0,"nomeServico":"Remoção de resíduos de pequenas reformas, móveis ou materiais inservíveis","etapasSelecionadas":{"catalogo":[{"codCatalogo":8994,"etapasDados":{"nomeServico":"8994","etapas":[41385,41391,41384]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":13,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":14,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":15,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":16,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":17,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":18,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":29,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":860550,"linha":null,"largura":null,"codEtapa":41384,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":87,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860754,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":95,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860737,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":130,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860751,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":140,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860736,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":143,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860752,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":157,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":860750,"linha":null,"largura":null,"codEtapa":41385,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11737,"codConfigColCatalogo":0,"nomeServico":"Coleta de resíduos sólidos de carcaças de animais para pessoa física","etapasSelecionadas":{"catalogo":[{"codCatalogo":11737,"etapasDados":{"nomeServico":"11737","etapas":[41417,41416]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":20,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":21,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":22,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":24,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":26,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":30,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":101,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":861549,"linha":null,"largura":null,"codEtapa":41416,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":306,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861762,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":326,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861745,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":372,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861756,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":440,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861759,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":460,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861744,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":464,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861760,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":509,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":861758,"linha":null,"largura":null,"codEtapa":41417,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null}]],"ativo":true,"dataCriacao":"2025-12-11T16:44:03.424Z","dateDataAlteracao":"2026-01-09T20:22:14.484Z","filtros":[],"campos":[],"filtroData":false,"parametrosFiltrosData":[],"id":"693af4d3ae003c36ccc8e7a0","dateDataAlteracaoFormatada":"09/01/2026"}"""
    
    df_solicitacoes = fetch_tabela(json_config)

    # Lista de strings a procurar
    strings_procuradas = ["logradouro", "Logradouro", "Número"]

    # Encontrar colunas que contenham qualquer uma das strings
    colunas_encontradas = [col for col in df_solicitacoes.columns if any(s in col for s in strings_procuradas)]

    df_solicitacoes = df_solicitacoes.drop(columns=colunas_encontradas)

    return df_solicitacoes, df_etapas


def tratar_nome_coluna(df_solicitacoes_etapa):
    # TRATAMENTOS
    # renomear colunas para o padrão
    rename_map = {
        "seqFluxo": "os",
        "Serviço": "servico",
        "Status Fluxo": "status_fluxo",
        "Data Finalização": "data_finalizacao",
        "Data Criação": "data_solicitacao",
        "Solicitante": "solicitante",
        "Bairro": "bairro",
        "Canal": "canal",
        "Tipo de registro": "tipo_registro",
        "etapa": "etapa",
        "executor": "executor",
    }

    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map)

    # capitalizar o nome do serviço para manter padrão
    df_solicitacoes_etapa['servico'] = df_solicitacoes_etapa['servico'].str.capitalize()

    # transformar datas para o formato correto
    df_solicitacoes_etapa['data_solicitacao'] = pd.to_datetime(df_solicitacoes_etapa['data_solicitacao'], format="ISO8601")
    df_solicitacoes_etapa['data_finalizacao'] = pd.to_datetime(df_solicitacoes_etapa['data_finalizacao'], format="ISO8601")


    # TEMPORÁRIO: voltar para nome da tb_os_acto
    rename_map_bi_asis = {
        "os": "n_da_solicitacao",
        "status_fluxo": "status",
        "data_finalizacao": "data_de_finalizacao",
        "data_solicitacao": "data_de_solicitacao",
        "nome_servico": "nome_do_servico_avaliado",
        "tipo_manifestacao": "tipo_de_manifestacao",
        "bairro": "bairro_consolidado",
        "tipo_registro": "tipo_de_registro",
        "etapa": "etapa_atual",
        "executor": "executor_atual",
    }
    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map_bi_asis)

    return df_solicitacoes_etapa


def main():

    df_solicitacoes, df_etapas = extrair_tabela_acto_gestao()

    COLUNAS = [
        "Nº Solicitação", "Serviço", "Data Finalização", "Status Fluxo", "Bairro", "Solicitante", "Data Criação", "Canal", "CPF", "Nome"
    ]
    for c in COLUNAS:
        df_solicitacoes = aplicar_bfill(df_solicitacoes, c)

    df_solicitacoes_etapa = adicionar_etapa_atual_2(df_etapas, df_solicitacoes)

    df_solicitacoes_etapa = tratar_nome_coluna(df_solicitacoes_etapa)

    df_solicitacoes_etapa = harmonizar_nome_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = aplicar_merge_prazo_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_datas_prazos(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_base_final_solicitacoes(df_solicitacoes_etapa)

    df_solicitacoes_etapa = remover_registros_teste(df_solicitacoes_etapa)

    # deixando igual ao tb_os_acto
    df = spark.sql("SELECT * FROM lh_cidade_inteligente_santos.tb_os_acto LIMIT 10").toPandas()
    df_solicitacoes_etapa = df_solicitacoes_etapa.reindex(columns=df.columns)

    return df_solicitacoes_etapa

df_solicitacoes_etapa = main()
# Out:
# StatementMeta(, 326f6494-c688-48db-9ccc-8848a6dc26ae, 10, Finished, Available, Finished)
# Status: 200
# ✅ Linhas em pandas: 366

# %%
sdf_solicitacoes_segov = spark.createDataFrame(df_solicitacoes_etapa)
(
    sdf_solicitacoes_segov
    .write.mode("overwrite")
    .format("delta")
    .option("overwriteSchema", "true")
    .saveAsTable("gold_segov_servicos")
)
# Out:
# StatementMeta(, 326f6494-c688-48db-9ccc-8848a6dc26ae, 12, Finished, Available, Finished)
