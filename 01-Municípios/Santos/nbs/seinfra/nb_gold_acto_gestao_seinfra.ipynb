# %%
# %run ./nb_utils_api_acto_gestao
# Out:
# StatementMeta(, 1fc8bab2-f16c-4df0-8136-ba0c758100e1, 9, Finished, Available, Finished)

# %%
import numpy as np

ARQUIVO_AUX = "abfss://96fe5a53-3a22-4443-8d0a-e2f6d61a2690@onelake.dfs.fabric.microsoft.com/0f8d9b0e-86cc-4454-9772-4ab92eb4db2a/Files/acto/tb_aux.xlsx"


def extrair_tabela_acto_gestao():

    df_etapas = obter_dados_etapa_atual(TOKEN, [11636, 11635, 11626, 11627, 11634, 11637])

    json_config = """{"nome":"seinfra_bi","solicitacoes":[[{"codCatalogo":11636,"codConfigColCatalogo":0,"nomeServico":"Choque elétrico em poste de iluminação pública","etapasSelecionadas":{"catalogo":[{"codCatalogo":11636,"etapasDados":{"nomeServico":"11636","etapas":[31554,31532,31524,31527]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":2,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":3,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":4,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":5,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":6,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":34,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":659860,"linha":null,"largura":null,"codEtapa":31524,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":253,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660097,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":259,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660076,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_EXECUCAO","tit":"Informe o responsável pela execução:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":294,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":709408,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":303,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660094,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":309,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660075,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":310,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":720790,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":311,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660095,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":323,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":660093,"linha":null,"largura":null,"codEtapa":31527,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":618,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":719734,"linha":null,"largura":null,"codEtapa":31532,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":655,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":660428,"linha":null,"largura":null,"codEtapa":31532,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":692,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":660249,"linha":null,"largura":null,"codEtapa":31554,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11635,"codConfigColCatalogo":0,"nomeServico":"Iluminação Fraca","etapasSelecionadas":{"catalogo":[{"codCatalogo":11635,"etapasDados":{"nomeServico":"11635","etapas":[40351,40348,40343,40346]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":7,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":8,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":9,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":10,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":11,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":12,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":50,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":814965,"linha":null,"largura":null,"codEtapa":40343,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_BAIRRO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":183,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815179,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":190,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815161,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":204,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815173,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOURONOME","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":242,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815176,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":256,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815160,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":258,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815116,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_NUMERO","tit":"Número:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":262,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815177,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOUROTIPO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":285,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815175,"linha":null,"largura":null,"codEtapa":40346,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":339,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":815332,"linha":null,"largura":null,"codEtapa":40348,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":514,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":815513,"linha":null,"largura":null,"codEtapa":40351,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":true,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":584,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":815564,"linha":null,"largura":null,"codEtapa":40351,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"RAD_EXECUTOR","tit":"Quem realizará a execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1127,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":815311,"linha":null,"largura":null,"codEtapa":40348,"json":null,"codCampo":5,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11626,"codConfigColCatalogo":0,"nomeServico":"Lâmpada ou luminária acesa durante o dia","etapasSelecionadas":{"catalogo":[{"codCatalogo":11626,"etapasDados":{"nomeServico":"11626","etapas":[40336,40333,40340,40342]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":13,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":17,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":21,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":25,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":29,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":33,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":146,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":813592,"linha":null,"largura":null,"codEtapa":40333,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":532,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813800,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":566,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813782,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":637,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813794,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_EXECUCAO","tit":"Informe o responsável pela execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":698,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813741,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":750,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813797,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":785,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813781,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":791,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813737,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":801,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813798,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":866,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":813796,"linha":null,"largura":null,"codEtapa":40336,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1270,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":814144,"linha":null,"largura":null,"codEtapa":40340,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1374,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":814194,"linha":null,"largura":null,"codEtapa":40340,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1529,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":813968,"linha":null,"largura":null,"codEtapa":40342,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11627,"codConfigColCatalogo":0,"nomeServico":"Lâmpada ou luminária piscando","etapasSelecionadas":{"catalogo":[{"codCatalogo":11627,"etapasDados":{"nomeServico":"11627","etapas":[40376,40373,40381,40378]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":14,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":18,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":22,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":26,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":30,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":35,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":148,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":816499,"linha":null,"largura":null,"codEtapa":40373,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_BAIRRO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":534,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816761,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":563,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816743,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":639,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816755,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_EXECUCAO","tit":"Informe o responsável pela execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":700,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816702,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOURONOME","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":752,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816758,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":781,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816742,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":792,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816698,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_NUMERO","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":803,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816759,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOUROTIPO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":862,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":816757,"linha":null,"largura":null,"codEtapa":40376,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":975,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":816904,"linha":null,"largura":null,"codEtapa":40378,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1549,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":817088,"linha":null,"largura":null,"codEtapa":40381,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1773,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":817138,"linha":null,"largura":null,"codEtapa":40381,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11634,"codConfigColCatalogo":0,"nomeServico":"Lâmpada ou luminária apagada","etapasSelecionadas":{"catalogo":[{"codCatalogo":11634,"etapasDados":{"nomeServico":"11634","etapas":[40356,40358,40353,40361]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":15,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":19,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":23,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":27,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":31,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":36,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":149,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":815673,"linha":null,"largura":null,"codEtapa":40353,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_BAIRRO","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":535,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815909,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":578,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815891,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":658,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815903,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_EXECUCAO","tit":"Informe o responsável pela execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":718,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815770,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOURONOME","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":770,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815906,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":804,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815890,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":809,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815766,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_NUMERO","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":821,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815907,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_ENDERECOREFERENCIA_LOGRADOUROTIPO","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":880,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":815905,"linha":null,"largura":null,"codEtapa":40356,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1033,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":816083,"linha":null,"largura":null,"codEtapa":40358,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1704,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":816269,"linha":null,"largura":null,"codEtapa":40361,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1903,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":816319,"linha":null,"largura":null,"codEtapa":40361,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null},{"codCatalogo":11637,"codConfigColCatalogo":0,"nomeServico":"Luminária ou poste tombados, danificados ou em risco de queda","etapasSelecionadas":{"catalogo":[{"codCatalogo":11637,"etapasDados":{"nomeServico":"11637","etapas":[40317,40314,40323,40321]}}]},"filtros":null,"servicos":[{"codConfigCol":null,"col":"seqFluxo","tit":"Nº Solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":16,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"servico","tit":"Serviço","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":20,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"statusFluxo","tit":"Status Fluxo","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":24,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataCriacao","tit":"Data Finalização","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":28,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"dataSolicitacao","tit":"Data Criação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":32,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"solicitante","tit":"Solicitante","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":37,"codCliente":0,"codConfigPagina":null,"etapa":null,"codFormularioCampo":null,"linha":null,"largura":null,"codEtapa":null,"json":null,"codCampo":0,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CANAL","tit":"Canal:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":151,"codCliente":0,"codConfigPagina":null,"etapa":"ABERTURA","codFormularioCampo":814266,"linha":null,"largura":null,"codEtapa":40314,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_BAIRRO_OCORRENCIA","tit":"Bairro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":536,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814589,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_CPF_INTERESSADO","tit":"CPF:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":570,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814571,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXA_DESCRICAO_SOLICITACAO","tit":"Detalhes da solicitação","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":642,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814583,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":3,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_EXECUCAO","tit":"Informe o responsável pela execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":704,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814430,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_LOGRADOURO_OCORRENCIA","tit":"Nome Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":755,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814586,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NOME_INTERESSADO","tit":"Nome:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":790,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814570,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_PLAQUETA","tit":"Número da plaqueta:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":795,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814426,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_NUMERO_OCORRENCIA","tit":"Número:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":806,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814587,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"TXT_TIPO_LOGRADOURO_OCORRENCIA","tit":"Tipo Logradouro:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":871,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE DE ÁREA","codFormularioCampo":814585,"linha":null,"largura":null,"codEtapa":40317,"json":null,"codCampo":2,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_EXECUCAO","tit":"Data e hora da execução do serviço:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1272,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":814451,"linha":null,"largura":null,"codEtapa":40321,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"CBO_CONCLUCAO_EXECUCAO","tit":"Status da execução:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1377,"codCliente":0,"codConfigPagina":null,"etapa":"ANÁLISE EXECUÇÃO","codFormularioCampo":814501,"linha":null,"largura":null,"codEtapa":40321,"json":null,"codCampo":7,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null},{"codConfigCol":null,"col":"DT_AGENDAMENTO","tit":"Agendamento:","visivel":true,"grafico":false,"totalizar":false,"contar":false,"agrupar":false,"grupo":false,"legenda":false,"sequencia":1535,"codCliente":0,"codConfigPagina":null,"etapa":"VISTORIA/ANÁLISE","codFormularioCampo":814744,"linha":null,"largura":null,"codEtapa":40323,"json":null,"codCampo":9,"codDomProcesso":0,"mask":null,"codProtocolo":null,"isVinculoAutomatico":0,"verificarCampoAntigo":0,"id":null}],"visivel":false,"grafico":false,"totalizar":false,"contar":false,"id":null}]],"ativo":true,"dataCriacao":"2025-12-10T11:37:19.81Z","dateDataAlteracao":"2026-01-19T17:04:43.595Z","filtros":[],"campos":[],"filtroData":false,"parametrosFiltrosData":[],"id":"69395b6fae003c36ccc8e799","dateDataAlteracaoFormatada":"19/01/2026"}"""
    
    df_solicitacoes = fetch_tabela(json_config)

    # Lista de strings a procurar
    strings_procuradas = ["logradouro", "Logradouro", "Número"]

    # Encontrar colunas que contenham qualquer uma das strings
    colunas_encontradas = [col for col in df_solicitacoes.columns if any(s in col for s in strings_procuradas)]

    df_solicitacoes = df_solicitacoes.drop(columns=colunas_encontradas)

    return df_solicitacoes, df_etapas


def tratar_nome_coluna(df_solicitacoes_etapa):
    # TRATAMENTOS
    # renomear colunas para o padrão
    rename_map = {
        "seqFluxo": "os",
        "Serviço": "servico",
        "Status Fluxo": "status_fluxo",
        "Data Finalização": "data_finalizacao",
        "Data Criação": "data_solicitacao",
        "Solicitante": "solicitante",
        "Bairro": "bairro",
        "Canal": "canal",
        "Tipo de registro": "tipo_registro",
        "etapa": "etapa",
        "executor": "executor",
        "Informe o responsável pela execução": "responsavel_execucao"
    }

    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map)

    # capitalizar o nome do serviço para manter padrão
    df_solicitacoes_etapa['servico'] = df_solicitacoes_etapa['servico'].str.capitalize()

    df_solicitacoes_etapa['responsavel_execucao'] = df_solicitacoes_etapa['responsavel_execucao'].replace("", np.nan)

    # transformar datas para o formato correto
    df_solicitacoes_etapa['data_solicitacao'] = pd.to_datetime(df_solicitacoes_etapa['data_solicitacao'], format="ISO8601")
    df_solicitacoes_etapa['data_finalizacao'] = pd.to_datetime(df_solicitacoes_etapa['data_finalizacao'], format="ISO8601")


    # TEMPORÁRIO: voltar para nome da tb_os_acto
    rename_map_bi_asis = {
        "os": "n_da_solicitacao",
        "status_fluxo": "status",
        "data_finalizacao": "data_de_finalizacao",
        "data_solicitacao": "data_de_solicitacao",
        "nome_servico": "nome_do_servico_avaliado",
        "tipo_manifestacao": "tipo_de_manifestacao",
        "bairro": "bairro_consolidado",
        "tipo_registro": "tipo_de_registro",
        "etapa": "etapa_atual",
        "executor": "executor_atual",
    }
    df_solicitacoes_etapa = df_solicitacoes_etapa.rename(columns=rename_map_bi_asis)

    return df_solicitacoes_etapa


def main():

    df_solicitacoes, df_etapas = extrair_tabela_acto_gestao()

    COLUNAS = [
        "Nº Solicitação", "Serviço", "Data Finalização", "Status Fluxo", "Bairro", "Solicitante", "Data Criação", "Canal", "CPF", "Nome", "Informe o responsável pela execução"
    ]
    for c in COLUNAS:
        df_solicitacoes = aplicar_bfill(df_solicitacoes, c)

    df_solicitacoes_etapa = adicionar_etapa_atual_2(df_etapas, df_solicitacoes)

    df_solicitacoes_etapa = tratar_nome_coluna(df_solicitacoes_etapa)

    df_solicitacoes_etapa = harmonizar_nome_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = aplicar_merge_prazo_bairros(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_datas_prazos(df_solicitacoes_etapa)

    df_solicitacoes_etapa = tratar_base_final_solicitacoes(df_solicitacoes_etapa)

    df_solicitacoes_etapa = remover_registros_teste(df_solicitacoes_etapa)

    # deixando igual ao tb_os_acto
    df = spark.sql("SELECT * FROM lh_cidade_inteligente_santos.tb_os_acto LIMIT 10").toPandas()
    df_solicitacoes_etapa = df_solicitacoes_etapa.reindex(columns=df.columns)

    return df_solicitacoes_etapa


df_solicitacoes_etapa = main()
# Out:
# StatementMeta(, 1fc8bab2-f16c-4df0-8136-ba0c758100e1, 84, Finished, Available, Finished)
# Status: 200
# ✅ Linhas em pandas: 1161

# %%
sdf_solicitacoes_seinfra = spark.createDataFrame(df_solicitacoes_etapa)
(
    sdf_solicitacoes_seinfra
    .write.mode("overwrite")
    .format("delta")
    .option("overwriteSchema", "true")
    .saveAsTable("gold_seinfra_servicos")
)
# Out:
# StatementMeta(, 1fc8bab2-f16c-4df0-8136-ba0c758100e1, 86, Finished, Available, Finished)
