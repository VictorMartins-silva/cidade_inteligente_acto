# %%
import pandas as pd
import numpy as np


ARQUIVO_TXT = "/lakehouse/default/Files/bronze_cad_unico/raw_cad_unico_marco26.TXT"
VERSAO = "2026-03-01"

dtypes_cols_reg1 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
    "DAT-CADASTRAMENTO-FAM", "DAT-ALTERACAO-FAM", "COD-EST-CADASTRAL-FAM",
    "IND-CADASTRO-VALIDO-FAM", "COD-CONDICAO-CADASTRO-FAM", "VLR-RENDA-MEDIA-FAM",
    "IND-TRABALHO-INFANTIL-FAM", "COD-MUNIC-IBGE-2-FAM", "COD-MUNIC-IBGE-5-FAM",
    "COD-IBGE-DISTRITO-FAM", "COD-IBGE-SUBDISTR-FAM", "COD-IBGE-SETOR-CENSO-FAM",
    "COD-MODALIDADE-FAM", "COD-FORMA-COLETA-FAM", "IND-FORMULARIO-0-FAM",
    "IND-FORMULARIO-1-FAM", "IND-FORMULARIO-2-FAM", "IND-FORMULARIO-SUP1-FAM",
    "IND-FORMULARIO-SUP2-FAM", "DTA-ENTREVISTA-FAM", "NOM-LOCALIDADE-FAM",
    "NOM-TIP-LOGRADOURO-FAM", "NOM-TITULO-LOGRADOURO-FAM", "NOM-LOGRADOURO-FAM",
    "NUM-LOGRADOURO-FAM", "DES-COMPLEMENTO-FAM", "DES-COMPLEMENTO-ADIC-FAM",
    "NUM-CEP-LOGRADOURO-FAM", "FILLER", "TXT-REFERENCIA-LOCAL-FAM",
    "NOM-ENTREVISTADOR-FAM", "NUM-CPF-ENTREVISTADOR-FAM", "TXT-OBS-ENTREVISTADOR-FAM",
    "COD-ORIGEM-PREFEITURA-FAM", "COD-ORIGEM-FAMILIA-FAM", "DT-CDSTR-ATUAL-FMLA",
    "FLAG-FAM-ALTERADA-V7", "DAT-ATUALIZACAO-FAMILIA", "COD-UNIDADE-TERRITORIAL-FAM",
    "NOM-UNIDADE-TERRITORIAL-FAM", "IND-FORMULARIO-SUP3-FAM", "NU-ORIGEM-CADASTRO-FAM",
    "DTA-INTEGRACAO-FAM", "DTA-INTEGRACAO-ESCOLARIDADE-FAM", "QTD_PES_CALC_RND",
    "CPF_USU_ALT_FAM", "COD-MOT-IMPOSSIB-VISITA-FAM",
]}

dtypes_cols_reg2 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
    "COD-LOCAL-DOMIC-FAM", "COD-ESPECIE-DOMIC-FAM", "QTD-COMODOS-DOMIC-FAM",
    "QTD-COMODOS-DORMITORIO-FAM", "COD-MATERIAL-PISO-FAM", "COD-MATERIAL-DOMIC-FAM",
    "COD-AGUA-CANALIZADA-FAM", "COD-ABASTE-AGUA-DOMIC-FAM", "COD-BANHEIRO-DOMIC-FAM",
    "COD-ESCOA-SANITARIO-DOMIC-FAM", "COD-DESTINO-LIXO-DOMIC-FAM",
    "COD-ILUMINACAO-DOMIC-FAM", "COD-CALCAMENTO-DOMIC-FAM",
]}

dtypes_cols_reg3 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
    "COD-FAMILIA-INDIGENA-FAM", "COD-POVO-INDIGENA-FAM", "NOM-POVO-INDIGENA-FAM",
    "Vazio2", "COD-INDIGENA-RESIDE-FAM", "COD-RESERVA-INDIGENA-FAM",
    "NOM-RESERVA-INDIGENA-FAM", "IND-RESERVA-INDIGENA-FAM", "IND-FAMILIA-QUILOMBOLA-FAM",
    "COD-COMUNIDADE-QUILOMBOLA-FAM", "NOM-COMUNIDADE-QUILOMBOLA-FAM",
    "IND-COMUNIDADE-QUILOMBOLA-FAM", "QTD-PESSOAS-DOMIC-FAM", "QTD-FAMILIAS-DOMIC-FAM",
    "QTD-PESSOA-INTER-0-17-ANOS-FAM", "IND-PESSOA-INTER-0-17-ANOS-FAM",
    "QTD-PESSOA-INTER-18-59-ANOS-FAM", "IND-PESSOA-INTER-18-59-ANOS-FAM",
    "QTD-PESSOA-INTER-60-ANOS-FAM", "IND-PESSOA-INTER-60-ANOS-FAM",
    "VAL-DESP-ENERGIA-FAM", "IND-DESP-ENERGIA-FAM", "VAL-DESP-AGUA-ESGOTO-FAM",
    "IND-DESP-AGUA-ESGOTO-FAM", "VAL-DESP-GAS-FAM", "IND-DESP-GAS-FAM",
    "VAL-DESP-ALIMENTACAO-FAM", "IND-DESP-ALIMENTACAO-FAM", "VAL-DESP-TRANSPOR-FAM",
    "IND-DESP-TRANSPOR-FAM", "VAL-DESP-ALUGUEL-FAM", "IND-DESP-ALUGUEL-FAM",
    "VAL-DESP-MEDICAMENTOS-FAM", "IND-DESP-MEDICAMENTOS-FAM", "NOM-ESTAB-ASSIST-SAUDE-FAM",
    "NU_ESTBO_SAUDE", "NOM-CENTRO-ASSIST-FAM", "COD-CENTRO-ASSIST-FAM",
    "IND-RISCO-SCL-VLCO-DRTS", "DT-INTGO-RSCO-SCL-VLCO-DRTS", "IND-RISCO-SCL-INSEG-ALIM",
    "DT-INTGO-RSCO-SCL-INSEG-ALIM",
]}

dtypes_cols_reg4 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
    "NUM-REG-ARQUIVO", "DTA-CADASTRAMENTO-MEMB", "DTA-ATUAL-MEMB",
    "COD-EST-CADASTRAL-MEMB", "IND-TRABALHO-INFANTIL-PESSOA", "NUM-ORDEM-PESSOA",
    "NOM-PESSOA", "NUM-NIS-PESSOA-ATUAL", "NOM-SOCIAL-PESSOA", "COD-SEXO-PESSOA",
    "DTA-NASC-PESSOA", "COD-PARENTESCO-RF-PESSOA", "COD-RACA-COR-PESSOA",
    "FILIACAO-1-NOM-COMPLETO-MAE-PESSOA", "IND-FILIACAO-1NOM-COMPLETO-MAE-PESSOA",
    "FILIACAO-2", "IND-FILIACAO-2", "COD-LOCAL-NASCIMENTO-PESSOA",
    "SIG-UF-MUNIC-NASC-PESSOA", "IND-UF-MUNIC-NASC-PESSOA", "NOM-IBGE-MUNIC-NASC-PESSOA",
    "COD-IBGE-MUNIC-NASC-PESSOA", "IND-IBGE-MUNIC-NASC-PESSOA", "NOM-PAIS-ORIGEM-PESSOA",
    "VAZIO", "IND-PAIS-ORIGEM-PESSOA", "COD-CERTIDAO-REGISTRADA-PESSOA",
    "COD-ORIGEM-PREFEITURA-PESSOA", "COD-ORIGEM-FAMILIA-PESSOA", "IND-TRANSFERÊNCIA-PESSOA",
    "NOM-ORIGEM-ALTERAÇÃO-PESSOA", "CHV-NAT-PES-ATUAL", "CHV-NAT-PES-ORIGINAL",
    "NU-NIS-ORIGINAL", "COD-PAIS-ORIGEM-PESSOA", "NU-ORIGEM-CADASTRO-PESSOA",
    "IND-IDENTIDADE-GENERO", "IND-TRANSGENERO", "NU-TIPO-IDENTIDADE-GENERO",
]}

dtypes_cols_reg5 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
    "NUM-REG-ARQUIVO", "COD-CERTIDAO-CIVIL-PESSOA", "NOM-CARTORIO-PESSOA",
    "COD-LIVRO-TERMO-CERTID-PESSOA", "COD-FOLHA-TERMO-CERTID-PESSOA",
    "VAZIO", "DTA-EMISSAO-CERTID-PESSOA", "SIG-UF-CERTID-PESSOA",
    "NOM-MUNIC-CERTID-PESSOA", "COD-IBGE-MUNIC-CERTID-PESSOA",
    "COD-CARTORIO-CERTID-PESSOA", "NUM-CPF-PESSOA", "VAZIO",
    "COD-COMPLEMENTO-PESSOA", "DTA-EMISSAO-IDENT-PESSOA", "SIG-UF-IDENT-PESSOA",
    "SIG-ORGAO-EMISSOR-PESSOA", "NUM-CART-TRAB-PREV-SOC-PESSOA",
    "NUM-SERIE-TRAB-PREV-SOC-PESSOA", "DTA-EMISSAO-CART-TRAB-PESSOA",
    "SIG-UF-CART-TRAB-PESSOA", "NUM-TITULO-ELEITOR-PESSOA", "NUM-ZONA-TIT-ELEITOR-PESSOA",
    "NUM-SECAO-TIT-ELEITOR-PESSOA", "COD-TERMO-MATRICULA-CERTID-PESSOA",
    "NUM-IDENTIDADE-PESSOA",
]}

dtypes_cols_reg6 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
    "NUM-REG-ARQUIVO", "COD-DEFICIENCIA-MEMB", "IND-DEF-CEGUEIRA-MEMB",
    "IND-DEF-BAIXA-VISAO-MEMB", "IND-DEF-SURDEZ-PROFUNDA-MEMB", "IND-DEF-SURDEZ-LEVE-MEMB",
    "IND-DEF-FISICA-MEMB", "IND-DEF-MENTAL-MEMB", "IND-DEF-SINDROME-DOWN-MEMB",
    "IND-DEF-TRANSTORNO-MENTAL-MEMB", "IND-AJUDA-NAO-MEMB", "IND-AJUDA-FAMILIA-MEMB",
    "IND-AJUDA-ESPECIALIZADO-MEMB", "IND-AJUDA-VIZINHO-MEMB", "IND-AJUDA-INSTITUICAO-MEMB",
    "IND-AJUDA-OUTRA-MEMB",
]}

dtypes_cols_reg7 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
    "NUM-REG-ARQUIVO", "COD-SABE-LER-ESCREVER-MEMB", "IND-FREQUENTA-ESCOLA-MEMB",
    "NOM-ESCOLA-MEMB", "COD-ESCOLA-LOCAL-MEMB", "SIG-UF-ESCOLA-MEMB",
    "NOM-MUNIC-ESCOLA-MEMB", "COD-IBGE-MUNIC-ESCOLA-MEMB", "COD-CENSO-INEP-MEMB",
    "IND-CENSO-INEP-MEMB", "COD-CURSO-FREQUENTA-MEMB", "COD-ANO-SERIE-FREQUENTA-MEMB",
    "COD-CURSO-FREQUENTOU-PESSOA-MEMB", "COD-ANO-SERIE-FREQUENTOU-MEMB",
    "COD-CONCLUIU-FREQUENTOU-MEMB", "COD-ORIGEM-DADOS-ESCOLARIDADE",
    "DTA-INTEGRACAO-ESCOLARIDADE-MEMBRO",
]}

dtypes_cols_reg9 = {
    "COD-FAMILIAR-FAM": str,
    "NUM-DDD-CONTATO-1-FAM": str,
    "NUM-TEL-CONTATO-1-FAM": str,
    "IC-TIPO-CONTATO-1-FAM": str,
    "IC-ENVO-SMS-CONTATO-1-FAM": str,
    "NUM-DDD-CONTATO-2-FAM": str,
    "NUM-TEL-CONTATO-2-FAM": str,
    "IC-TIPO-CONTATO-2-FAM": str,
    "IC-ENVO-SMS-CONTATO-2-FAM": str,
    "IC-TIPO-EMAIL-FAM": str,
    "EMAIL-FAM": str,
    "IC-ENVIO-EMAIL-FAM": str,
}
dtypes_cols_reg14 = {
    "COD-FAMILIAR-FAM": str,
    "NUM-MEMBRO-FMLA": str,
}
dtypes_cols_reg16 = {
    "COD-FAMILIAR-FAMT": str,
    "DAT-TRANSFERÊNCIA-FAMT": str,
    "COD-EST-CADASTRAL-ATUAL-FAMT": str,
    "COD-MUNIC-IBGE-ORIGEM-2-FAMT": str,
    "COD-MUNIC-IBGE-ORIGEM-5-FAMT": str,
    "COD-DESTINO-PREFEITURA-FAMT": str,
    "COD-DESTINO-FAMILIA-FAMT": str,
}
dtypes_cols_reg17 = {
    "COD-FAMILIAR-MEMBT": str,
    "NUM-MEMBRO-FMLA": str,
    "DTA-TRANSFERENCIA-MEMBT": str,
    "COD-EST-CADASTRAL-ATUAL-MEMBT": str,
    "NOM-MEMB-T": str,
    "NUM-NIS-MEMBT": str,
    "NOM-APELIDO-MEMBT": str,
    "COD-SEXO-MEMBT": str,
    "DTA-NASC-MEMBT": str,
    "COD-RACA-COR-MEMBT": str,
}
dtypes_cols_reg18 = {col: str for col in [
    "CHV-NATURAL-PREFEITURA-FAM-EXC",
    "COD-FAMILIAR-FAM-EXC",
    "VAZIO",
    "NUM-REG-ARQUIVO",
    "DATA-EXC",
    "CPF-OPER-EXC",
    "MOTIVO-EXC",
    "NUM-PGMCU",
    "DAT-EMI-PGMCU",
    "NOM-SERVD-PBCO-PGMCU",
    "CPF-SERVD-PBCO-PGMCU-PGMCU",
    "UF-PGMCU",
    "MUN-PGMCU",
    "DESC-MOT-EXC",
]}


def processar_txt_cadunico():
    blocos = {}
    with open(f"{ARQUIVO_TXT}", encoding="cp850") as f:
        lines = f.readlines()

    # 2 primeiras linhas são cabeçalho
    for line in lines[2:]:
        codigo_bloco = line[37:39]
        if codigo_bloco not in blocos:
            blocos[codigo_bloco] = []
        blocos[codigo_bloco].append(line)

    def gerar_txt_bloco(n_bloco):
        # Exporta o bloco para txt separado para ler na sequencia
        if f"{n_bloco:02}" in blocos:
            with open(f"/lakehouse/default/Files/bronze_cad_unico/bloco_{n_bloco:02}.txt", "w", encoding="cp850") as f:
                f.writelines(blocos[f"{n_bloco:02}"])
        return None

    codigo_blocos = [1, 2, 3, 4, 5, 6, 7, 9, 14, 16, 17, 18]
    for n in codigo_blocos:
        gerar_txt_bloco(n)


def ler_bloco_01():
    colnames_01 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
        "DAT-CADASTRAMENTO-FAM", "DAT-ALTERACAO-FAM", "COD-EST-CADASTRAL-FAM",
        "IND-CADASTRO-VALIDO-FAM", "COD-CONDICAO-CADASTRO-FAM", "VLR-RENDA-MEDIA-FAM",
        "IND-TRABALHO-INFANTIL-FAM", "COD-MUNIC-IBGE-2-FAM", "COD-MUNIC-IBGE-5-FAM",
        "COD-IBGE-DISTRITO-FAM", "COD-IBGE-SUBDISTR-FAM", "COD-IBGE-SETOR-CENSO-FAM",
        "COD-MODALIDADE-FAM", "COD-FORMA-COLETA-FAM", "IND-FORMULARIO-0-FAM",
        "IND-FORMULARIO-1-FAM", "IND-FORMULARIO-2-FAM", "IND-FORMULARIO-SUP1-FAM",
        "IND-FORMULARIO-SUP2-FAM", "DTA-ENTREVISTA-FAM", "NOM-LOCALIDADE-FAM",
        "NOM-TIP-LOGRADOURO-FAM", "NOM-TITULO-LOGRADOURO-FAM", "NOM-LOGRADOURO-FAM",
        "NUM-LOGRADOURO-FAM", "DES-COMPLEMENTO-FAM", "DES-COMPLEMENTO-ADIC-FAM",
        "NUM-CEP-LOGRADOURO-FAM", "FILLER", "TXT-REFERENCIA-LOCAL-FAM",
        "NOM-ENTREVISTADOR-FAM", "NUM-CPF-ENTREVISTADOR-FAM", "TXT-OBS-ENTREVISTADOR-FAM",
        "COD-ORIGEM-PREFEITURA-FAM", "COD-ORIGEM-FAMILIA-FAM", "DT-CDSTR-ATUAL-FMLA",
        "FLAG-FAM-ALTERADA-V7", "DAT-ATUALIZACAO-FAMILIA", "COD-UNIDADE-TERRITORIAL-FAM",
        "NOM-UNIDADE-TERRITORIAL-FAM", "IND-FORMULARIO-SUP3-FAM", "NU-ORIGEM-CADASTRO-FAM",
        "DTA-INTEGRACAO-FAM", "DTA-INTEGRACAO-ESCOLARIDADE-FAM", "QTD_PES_CALC_RND",
        "CPF_USU_ALT_FAM", "COD-MOT-IMPOSSIB-VISITA-FAM",
    ]

    colspecs_01_access = [
        (1, 13), (14, 11), (25, 13), (38, 2), (40, 8), (48, 8), (56, 1), (57, 1),
        (58, 1), (59, 9), (68, 1), (69, 2), (71, 5), (76, 2), (78, 2), (80, 4),
        (84, 1), (85, 1), (86, 1), (87, 1), (88, 1), (89, 1), (90, 1), (91, 8),
        (99, 76), (175, 38), (213, 38), (251, 76), (327, 16), (343, 22), (365, 75),
        (440, 8), (448, 38), (486, 256), (742, 70), (812, 11), (823, 256), (1079, 13),
        (1092, 11), (1103, 8), (1111, 1), (1112, 8), (1120, 10), (1130, 100), (1230, 1),
        (1231, 2), (1233, 8), (1241, 8), (1249, 3), (1252, 11), (1263, 1),
    ]

    colspecs_01_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_01_access
    ]

    df_reg01 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_01.txt",
        colspecs=colspecs_01_pandas,
        names=colnames_01,
        encoding="cp850",
        dtype=dtypes_cols_reg1,
    )

    df_reg01.columns = df_reg01.columns.str.lower().str.replace("-", "_")
    return df_reg01


def ler_bloco_02():
    colnames_02 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
        "COD-LOCAL-DOMIC-FAM", "COD-ESPECIE-DOMIC-FAM", "QTD-COMODOS-DOMIC-FAM",
        "QTD-COMODOS-DORMITORIO-FAM", "COD-MATERIAL-PISO-FAM", "COD-MATERIAL-DOMIC-FAM",
        "COD-AGUA-CANALIZADA-FAM", "COD-ABASTE-AGUA-DOMIC-FAM", "COD-BANHEIRO-DOMIC-FAM",
        "COD-ESCOA-SANITARIO-DOMIC-FAM", "COD-DESTINO-LIXO-DOMIC-FAM",
        "COD-ILUMINACAO-DOMIC-FAM", "COD-CALCAMENTO-DOMIC-FAM",
    ]

    colspecs_02_access = [
        (1, 13), (14, 11), (25, 13), (38, 2), (40, 1), (41, 1), (42, 2), (44, 2),
        (46, 1), (47, 1), (48, 1), (49, 1), (50, 1), (51, 1), (52, 1), (53, 1), (54, 1),
    ]

    colspecs_02_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_02_access
    ]

    df_reg02 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_02.txt",
        colspecs=colspecs_02_pandas,
        names=colnames_02,
        encoding="cp850",
        dtype=dtypes_cols_reg2,
    )

    df_reg02.columns = df_reg02.columns.str.lower().str.replace("-", "_")
    return df_reg02


def ler_bloco_03():
    colnames_03 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "VAZIO", "NUM-REG-ARQUIVO",
        "COD-FAMILIA-INDIGENA-FAM", "COD-POVO-INDIGENA-FAM", "NOM-POVO-INDIGENA-FAM",
        "Vazio2", "COD-INDIGENA-RESIDE-FAM", "COD-RESERVA-INDIGENA-FAM",
        "NOM-RESERVA-INDIGENA-FAM", "IND-RESERVA-INDIGENA-FAM", "IND-FAMILIA-QUILOMBOLA-FAM",
        "COD-COMUNIDADE-QUILOMBOLA-FAM", "NOM-COMUNIDADE-QUILOMBOLA-FAM",
        "IND-COMUNIDADE-QUILOMBOLA-FAM", "QTD-PESSOAS-DOMIC-FAM", "QTD-FAMILIAS-DOMIC-FAM",
        "QTD-PESSOA-INTER-0-17-ANOS-FAM", "IND-PESSOA-INTER-0-17-ANOS-FAM",
        "QTD-PESSOA-INTER-18-59-ANOS-FAM", "IND-PESSOA-INTER-18-59-ANOS-FAM",
        "QTD-PESSOA-INTER-60-ANOS-FAM", "IND-PESSOA-INTER-60-ANOS-FAM",
        "VAL-DESP-ENERGIA-FAM", "IND-DESP-ENERGIA-FAM", "VAL-DESP-AGUA-ESGOTO-FAM",
        "IND-DESP-AGUA-ESGOTO-FAM", "VAL-DESP-GAS-FAM", "IND-DESP-GAS-FAM",
        "VAL-DESP-ALIMENTACAO-FAM", "IND-DESP-ALIMENTACAO-FAM", "VAL-DESP-TRANSPOR-FAM",
        "IND-DESP-TRANSPOR-FAM", "VAL-DESP-ALUGUEL-FAM", "IND-DESP-ALUGUEL-FAM",
        "VAL-DESP-MEDICAMENTOS-FAM", "IND-DESP-MEDICAMENTOS-FAM", "NOM-ESTAB-ASSIST-SAUDE-FAM",
        "NU_ESTBO_SAUDE", "NOM-CENTRO-ASSIST-FAM", "COD-CENTRO-ASSIST-FAM",
        "IND-RISCO-SCL-VLCO-DRTS", "DT-INTGO-RSCO-SCL-VLCO-DRTS", "IND-RISCO-SCL-INSEG-ALIM",
        "DT-INTGO-RSCO-SCL-INSEG-ALIM",
    ]

    colspecs_03_access = [
        (1, 13), (14, 11), (25, 13), (38, 2), (40, 1), (41, 3), (44, 70), (114, 1),
        (115, 1), (116, 6), (122, 70), (192, 1), (193, 1), (194, 4), (198, 120),
        (318, 1), (319, 2), (321, 2), (323, 2), (325, 1), (326, 2), (328, 1), (329, 2),
        (331, 1), (332, 5), (337, 1), (338, 5), (343, 1), (344, 5), (349, 1), (350, 5),
        (355, 1), (356, 5), (361, 1), (362, 5), (367, 1), (368, 5), (373, 1), (374, 70),
        (444, 12), (456, 70), (526, 12), (538, 1), (539, 8), (547, 1), (548, 8),
    ]

    colspecs_03_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_03_access
    ]

    df_reg03 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_03.txt",
        colspecs=colspecs_03_pandas,
        names=colnames_03,
        encoding="cp850",
        dtype=dtypes_cols_reg3,
    )

    df_reg03.columns = df_reg03.columns.str.lower().str.replace("-", "_")
    return df_reg03


def ler_bloco_04():
    colnames_04 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
        "NUM-REG-ARQUIVO", "DTA-CADASTRAMENTO-MEMB", "DTA-ATUAL-MEMB",
        "COD-EST-CADASTRAL-MEMB", "IND-TRABALHO-INFANTIL-PESSOA", "NUM-ORDEM-PESSOA",
        "NOM-PESSOA", "NUM-NIS-PESSOA-ATUAL", "NOM-SOCIAL-PESSOA", "COD-SEXO-PESSOA",
        "DTA-NASC-PESSOA", "COD-PARENTESCO-RF-PESSOA", "COD-RACA-COR-PESSOA",
        "FILIACAO-1-NOM-COMPLETO-MAE-PESSOA", "IND-FILIACAO-1NOM-COMPLETO-MAE-PESSOA",
        "FILIACAO-2", "IND-FILIACAO-2", "COD-LOCAL-NASCIMENTO-PESSOA",
        "SIG-UF-MUNIC-NASC-PESSOA", "IND-UF-MUNIC-NASC-PESSOA", "NOM-IBGE-MUNIC-NASC-PESSOA",
        "COD-IBGE-MUNIC-NASC-PESSOA", "IND-IBGE-MUNIC-NASC-PESSOA", "NOM-PAIS-ORIGEM-PESSOA",
        "VAZIO2", "IND-PAIS-ORIGEM-PESSOA", "COD-CERTIDAO-REGISTRADA-PESSOA",
        "COD-ORIGEM-PREFEITURA-PESSOA", "COD-ORIGEM-FAMILIA-PESSOA", "IND-TRANSFERÊNCIA-PESSOA",
        "NOM-ORIGEM-ALTERAÇÃO-PESSOA", "CHV-NAT-PES-ATUAL", "CHV-NAT-PES-ORIGINAL",
        "NU-NIS-ORIGINAL", "COD-PAIS-ORIGEM-PESSOA", "NU-ORIGEM-CADASTRO-PESSOA",
        "IND-IDENTIDADE-GENERO", "IND-TRANSGENERO", "NU-TIPO-IDENTIDADE-GENERO",
    ]

    colspecs_04_access = [
        (1, 13), (14, 11), (25, 11), (36, 2), (38, 2), (40, 8), (48, 8), (56, 1),
        (57, 1), (58, 2), (60, 70), (130, 11), (141, 34), (175, 1), (176, 8), (184, 2),
        (186, 1), (187, 70), (257, 1), (258, 70), (328, 1), (329, 1), (330, 2), (332, 1),
        (333, 35), (368, 7), (375, 1), (376, 40), (416, 2), (418, 1), (419, 1), (420, 13),
        (433, 11), (444, 1), (445, 60), (505, 13), (518, 13), (531, 11), (542, 4),
        (546, 2), (548, 1), (549, 1), (550, 3),
    ]

    colspecs_04_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_04_access
    ]

    df_reg04 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_04.txt",
        colspecs=colspecs_04_pandas,
        names=colnames_04,
        encoding="cp850",
        dtype=dtypes_cols_reg4,
    )

    df_reg04.columns = df_reg04.columns.str.lower().str.replace("-", "_")
    return df_reg04


def ler_bloco_05():
    colnames_05 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
        "NUM-REG-ARQUIVO", "COD-CERTIDAO-CIVIL-PESSOA", "NOM-CARTORIO-PESSOA",
        "COD-LIVRO-TERMO-CERTID-PESSOA", "COD-FOLHA-TERMO-CERTID-PESSOA",
        "VAZIO2", "DTA-EMISSAO-CERTID-PESSOA", "SIG-UF-CERTID-PESSOA",
        "NOM-MUNIC-CERTID-PESSOA", "COD-IBGE-MUNIC-CERTID-PESSOA",
        "COD-CARTORIO-CERTID-PESSOA", "NUM-CPF-PESSOA", "VAZIO3",
        "COD-COMPLEMENTO-PESSOA", "DTA-EMISSAO-IDENT-PESSOA", "SIG-UF-IDENT-PESSOA",
        "SIG-ORGAO-EMISSOR-PESSOA", "NUM-CART-TRAB-PREV-SOC-PESSOA",
        "NUM-SERIE-TRAB-PREV-SOC-PESSOA", "DTA-EMISSAO-CART-TRAB-PESSOA",
        "SIG-UF-CART-TRAB-PESSOA", "NUM-TITULO-ELEITOR-PESSOA", "NUM-ZONA-TIT-ELEITOR-PESSOA",
        "NUM-SECAO-TIT-ELEITOR-PESSOA", "COD-TERMO-MATRICULA-CERTID-PESSOA",
        "NUM-IDENTIDADE-PESSOA",
    ]

    colspecs_05_access = [
        (1, 13), (14, 11), (25, 11), (36, 2), (38, 2), (40, 1), (41, 70), (111, 8),
        (119, 4), (123, 8), (131, 8), (139, 2), (141, 35), (176, 7), (183, 15),
        (198, 11), (209, 16), (225, 5), (230, 8), (238, 2), (240, 8), (248, 7),
        (255, 5), (260, 8), (268, 2), (270, 13), (283, 4), (287, 4), (291, 32), (323, 20),
    ]

    colspecs_05_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_05_access
    ]

    df_reg05 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_05.txt",
        colspecs=colspecs_05_pandas,
        names=colnames_05,
        encoding="cp850",
        dtype=dtypes_cols_reg5,
    )

    df_reg05.columns = df_reg05.columns.str.lower().str.replace("-", "_")
    return df_reg05


def ler_bloco_06():
    colnames_06 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
        "NUM-REG-ARQUIVO", "COD-DEFICIENCIA-MEMB", "IND-DEF-CEGUEIRA-MEMB",
        "IND-DEF-BAIXA-VISAO-MEMB", "IND-DEF-SURDEZ-PROFUNDA-MEMB", "IND-DEF-SURDEZ-LEVE-MEMB",
        "IND-DEF-FISICA-MEMB", "IND-DEF-MENTAL-MEMB", "IND-DEF-SINDROME-DOWN-MEMB",
        "IND-DEF-TRANSTORNO-MENTAL-MEMB", "IND-AJUDA-NAO-MEMB", "IND-AJUDA-FAMILIA-MEMB",
        "IND-AJUDA-ESPECIALIZADO-MEMB", "IND-AJUDA-VIZINHO-MEMB", "IND-AJUDA-INSTITUICAO-MEMB",
        "IND-AJUDA-OUTRA-MEMB",
    ]

    colspecs_06_access = [
        (1, 13), (14, 11), (25, 11), (36, 2), (38, 2), (40, 1), (41, 1), (42, 1),
        (43, 1), (44, 1), (45, 1), (46, 1), (47, 1), (48, 1), (49, 1), (50, 1),
        (51, 1), (52, 1), (53, 1), (54, 1),
    ]

    colspecs_06_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_06_access
    ]

    df_reg06 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_06.txt",
        colspecs=colspecs_06_pandas,
        names=colnames_06,
        encoding="cp850",
        dtype=dtypes_cols_reg6,
    )

    df_reg06.columns = df_reg06.columns.str.lower().str.replace("-", "_")
    return df_reg06


def ler_bloco_07():
    colnames_07 = [
        "CHV-NATURAL-PREFEITURA-FAM", "COD-FAMILIAR-FAM", "NUM-MEMBRO-FMLA", "VAZIO",
        "NUM-REG-ARQUIVO", "COD-SABE-LER-ESCREVER-MEMB", "IND-FREQUENTA-ESCOLA-MEMB",
        "NOM-ESCOLA-MEMB", "COD-ESCOLA-LOCAL-MEMB", "SIG-UF-ESCOLA-MEMB",
        "NOM-MUNIC-ESCOLA-MEMB", "COD-IBGE-MUNIC-ESCOLA-MEMB", "COD-CENSO-INEP-MEMB",
        "IND-CENSO-INEP-MEMB", "COD-CURSO-FREQUENTA-MEMB", "COD-ANO-SERIE-FREQUENTA-MEMB",
        "COD-CURSO-FREQUENTOU-PESSOA-MEMB", "COD-ANO-SERIE-FREQUENTOU-MEMB",
        "COD-CONCLUIU-FREQUENTOU-MEMB", "COD-ORIGEM-DADOS-ESCOLARIDADE",
        "DTA-INTEGRACAO-ESCOLARIDADE-MEMBRO",
    ]

    colspecs_07_access = [
        (1, 13), (14, 11), (25, 11), (36, 2), (38, 2), (40, 1), (41, 1), (42, 70),
        (112, 1), (113, 2), (115, 35), (150, 7), (157, 8), (165, 1), (166, 2),
        (168, 2), (170, 2), (172, 2), (174, 1), (175, 1), (176, 8),
    ]

    colspecs_07_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_07_access
    ]

    df_reg07 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_07.txt",
        colspecs=colspecs_07_pandas,
        names=colnames_07,
        encoding="cp850",
        dtype=dtypes_cols_reg7,
    )

    df_reg07.columns = df_reg07.columns.str.lower().str.replace("-", "_")
    return df_reg07


def ler_bloco_09():
    colnames_09 = [
        "CHV-NATURAL-PREFEITURA-FAM",
        "COD-FAMILIAR-FAM",
        "VAZIO",
        "NUM-REG-ARQUIVO",
        "NUM-DDD-CONTATO-1-FAM",
        "NUM-TEL-CONTATO-1-FAM",
        "IC-TIPO-CONTATO-1-FAM",
        "IC-ENVO-SMS-CONTATO-1-FAM",
        "NUM-DDD-CONTATO-2-FAM",
        "NUM-TEL-CONTATO-2-FAM",
        "IC-TIPO-CONTATO-2-FAM",
        "IC-ENVO-SMS-CONTATO-2-FAM",
        "IC-TIPO-EMAIL-FAM",
        "EMAIL-FAM",
        "IC-ENVIO-EMAIL-FAM",
        "IC-ARQUIVOS-CARREGADOS",
        "DATA-ARQUIVOS-CARREGADOS",
        "CPF-OPERADOR-RESPONSAVEL",
    ]

    colspecs_09_access = [
        (1, 13),
        (14, 11),
        (25, 13),
        (38, 2),
        (40, 2),
        (42, 10),
        (52, 1),
        (53, 1),
        (54, 2),
        (56, 10),
        (66, 1),
        (67, 1),
        (68, 1),
        (69, 50),
        (119, 1),
        (120, 1),
        (121, 8),
        (129, 11),
    ]

    colspecs_09_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_09_access
    ]

    df_reg09 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_09.txt",
        colspecs=colspecs_09_pandas,
        names=colnames_09,
        encoding="cp850",
        dtype=dtypes_cols_reg9,
    )

    df_reg09.columns = df_reg09.columns.str.lower().str.replace("-", "_")

    return df_reg09


def ler_bloco_14():
    colnames_14 = [
        "CHV-NATURAL-PREFEITURA-FAM",
        "COD-FAMILIAR-FAM",
        "NUM-MEMBRO-FMLA",
        "VAZIO",
        "NUM-REG-ARQUIVO",
        "IND-PTAB-DESAT-INEP-MEMB",
        "IND-PMIG-CPO-OBR-MEMB",
        "IND-PMIG-SEM-DOC-MEMB",
        "IND-PMIG-RF-CPF-ELEITOR-MEMB",
        "IND-PMIG-RF-CPF-INV-MEMB",
        "IND-PMIG-RF-CPF-MULT-MEMB",
        "IND-PMIG-MEMB-CPF-MULT-MEMB",
        "IND-PMIG-RF-CPF-TITULAR-MEMB",
        "IND-PMIG-MEMB-CPF-TITULAR-MEMB",
        "IND-PMIG-RF-ELEITOR-INV-MEMB",
        "IND-PMIG-RF-ELEITOR-MULT-MEMB",
        "IND-PMIG-MEMB-CPF-INV-MEMB",
        "IND-PMIG-MEMB-ELEITOR-MULT-MEMB",
        "IND-PMIG-RF-IDADE-16-MEMB",
        "IND-PTRN-MEMB-INEP-MEMB",
        "IND-PTRN-MEMB-PARENTE-MEMB",
        "IND-PAUD-CPO-OBR-MEMB",
        "IND-PAUD-RF-CPF-ELEITOR-MEMB",
        "IND-PAUD-RF-CPF-INV-MEMB",
        "IND-PAUD-RF-CPF-MULT-MEMB",
        "IND-PAUD-MEMB-CPF-MULT-MEMB",
        "IND-PAUD-RF-CPF-TITULAR-MEMB",
        "IND-PAUD-MEMB-CPF-TITULAR-MEMB",
        "IND-PAUD-MEMB-CPF-INV-MEMB",
        "IND-PAUD-MEMB-ELEITOR-INV-MEMB",
        "IND-PAUD-RF-ELEITOR-INV-MEMB",
        "IND-PAUD-MEMB-ELEITOR-MULT-MEMB",
        "IND-PAUD-RF-IDADE-16-MEMB",
        "IND-PAUD-REJEI-MEMB",
        "IND-OTRN-OUTRO-MUN-PES",
        "IND-OTRN-NOVA-PES",
        "IND-OTRN-EXIST-PES",
        "IND-OTRN-OUTRA-PES",
        "IND-OSRG-SEM-CERTIDAO-PES",
        "IND-OSRG-SEM-REGISTRO-PES",
        "IND-OSRG-NAO-SABE-PES",
        "IND-PAUD-MBO-CAD-COM-CERT-OBIT",
        "IND-OAUD-MEMB-IND-OBTO-NEG",
        "IND-PAUD-RF-ELEITOR-MULT-MEMB",
        "IND-OAUD-MEMB-MULT-CTPS",
        "IND-OAUD-MEMB-MULT-RCN",
        "IND-OAUD-MEMB-MULT-RG",
        "IND-PAUD-CPF-CANCEL-RECEITA",
        "IND-PAUD-CPF-SUSP-RECEITA",
        "IND-PAUD-MEMB-OBTO-ORIG-ARQ",
        "DT-PAUD-CPO-OBR-MEMB",
        "DT-PAUD-RF-CPF-INV-MEMB",
        "DT-PAUD-RF-CPF-MULT-MEMB",
        "DT-PAUD-MEMB-CPF-MULT-MEMB",
        "DT-PAUD-RF-CPF-TITULAR-MEMB",
        "DT-PAUD-MEMB-CPF-TITULAR-MEMB",
        "DT-PAUD-RF-ELEITOR-MULT-MEMB",
        "DT-PAUD-MEMB-ELEITOR-MULT-MEMB",
        "DT-PAUD-MEMB-IND-OBTO",
        "DT-PAUD-MEMB-OBTO-ORIG-ARQ",
        "DT-OAUD-MEMB-IND-OBTO-REJ",
        "DT-PAUD-CPF-CANCEL-RECEITA",
        "DT-PAUD-CPF-SUSP-RECEITA",
    ]

    colspecs_14_access = [
        (1, 13),
        (14, 11),
        (25, 11),
        (36, 2),
        (38, 2),
        (40, 1),
        (41, 1),
        (42, 1),
        (43, 1),
        (44, 1),
        (45, 1),
        (46, 1),
        (47, 1),
        (48, 1),
        (49, 1),
        (50, 1),
        (51, 1),
        (52, 1),
        (53, 1),
        (54, 1),
        (55, 1),
        (56, 1),
        (57, 1),
        (58, 1),
        (59, 1),
        (60, 1),
        (61, 1),
        (62, 1),
        (63, 1),
        (64, 1),
        (65, 1),
        (66, 1),
        (67, 1),
        (68, 1),
        (69, 1),
        (70, 1),
        (71, 1),
        (72, 1),
        (73, 1),
        (74, 1),
        (75, 1),
        (76, 1),
        (77, 1),
        (78, 1),
        (79, 1),
        (80, 1),
        (81, 1),
        (82, 1),
        (83, 1),
        (84, 1),
        (85, 8),
        (93, 8),
        (101, 8),
        (109, 8),
        (117, 8),
        (125, 8),
        (133, 8),
        (141, 8),
        (149, 8),
        (157, 8),
        (165, 8),
        (173, 8),
        (181, 8),
    ]

    colspecs_14_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_14_access
    ]

    df_reg14 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_14.txt",
        colspecs=colspecs_14_pandas,
        names=colnames_14,
        encoding="cp850",
        dtype=dtypes_cols_reg14,
    )

    df_reg14.columns = df_reg14.columns.str.lower().str.replace("-", "_")

    return df_reg14


def ler_bloco_16():
    colnames_16 = [
        "CHV-NATURAL-PREFEITURA-FAMT",
        "COD-FAMILIAR-FAMT",
        "VAZIO",
        "NUM-REG-ARQUIVO-FAMT",
        "DAT-TRANSFERÊNCIA-FAMT",
        "COD-EST-CADASTRAL-ATUAL-FAMT",
        "COD-MUNIC-IBGE-ORIGEM-2-FAMT",
        "COD-MUNIC-IBGE-ORIGEM-5-FAMT",
        "COD-DESTINO-PREFEITURA-FAMT",
        "COD-DESTINO-FAMILIA-FAMT",
    ]

    colspecs_16_access = [
        (1, 13),
        (14, 11),
        (25, 13),
        (38, 2),
        (40, 8),
        (48, 1),
        (49, 2),
        (51, 5),
        (56, 13),
        (69, 11),
    ]

    colspecs_16_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_16_access
    ]

    df_reg16 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_16.txt",
        colspecs=colspecs_16_pandas,
        names=colnames_16,
        encoding="cp850",
        dtype=dtypes_cols_reg16,
    )

    df_reg16.columns = df_reg16.columns.str.lower().str.replace("-", "_")

    return df_reg16


def ler_bloco_17():
    colnames_17 = [
        "CHV-NATURAL-PREFEITURA-MEMBT",
        "COD-FAMILIAR-MEMBT",
        "NUM-MEMBRO-FMLA",
        "VAZIO",
        "NUM-REG-ARQUIVO",
        "DTA-TRANSFERENCIA-MEMBT",
        "COD-EST-CADASTRAL-ATUAL-MEMBT",
        "NOM-MEMB-T",
        "NUM-NIS-MEMBT",
        "NOM-APELIDO-MEMBT",
        "COD-SEXO-MEMBT",
        "DTA-NASC-MEMBT",
        "COD-RACA-COR-MEMBT",
        "FILIACAO-1-NOM-COMPLETO-MAE-MEMBT",
        "IND-FILIACAO-1-NOM-COMPLETO-MAE-MEMBT",
        "FILIACAO-2",
        "IND-FILIACAO-2",
        "VAZIO2",
        "SIG-UF-MUNIC-NASC-MEMBT",
        "IND-UF-MUNIC-NASC-MEMBT",
        "NOM-IBGE-MUNIC-NASC-MEMBT",
        "COD-IBGE-MUNIC-NASC-MEMBT",
        "IND-IBGE-MUNIC-NASC-MEMBT",
        "NOM-PAIS-ORIGEM-MEMBT",
        "VAZIO3",
        "IND-PAIS-ORIGEM-MEMBT",
        "COD-CERTIDAO-REGISTRADA-MEMBT",
        "COD-DESTINO-PREFEITURA-MEMBT",
        "COD-DESTINO-FAMILIA-MEMBT",
        "COD-PAIS-ORIGEM-MEMBT",
    ]

    colspecs_17_access = [
        (1, 13),
        (14, 11),
        (25, 11),
        (36, 2),
        (38, 2),
        (40, 8),
        (48, 1),
        (49, 70),
        (119, 11),
        (130, 34),
        (164, 1),
        (165, 8),
        (173, 1),
        (174, 70),
        (244, 1),
        (245, 70),
        (315, 1),
        (316, 1),
        (317, 2),
        (319, 1),
        (320, 35),
        (355, 7),
        (362, 1),
        (363, 40),
        (403, 2),
        (405, 1),
        (406, 1),
        (407, 13),
        (420, 11),
        (431, 4),
    ]

    colspecs_17_pandas = [
        (inicio - 1, (inicio - 1) + largura) for inicio, largura in colspecs_17_access
    ]

    df_reg17 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_17.txt",
        colspecs=colspecs_17_pandas,
        names=colnames_17,
        encoding="cp850",
        dtype=dtypes_cols_reg17,
    )

    df_reg17.columns = df_reg17.columns.str.lower().str.replace("-", "_")

    return df_reg17


def ler_bloco_18():
    colnames_18 = [
        "CHV-NATURAL-PREFEITURA-FAM-EXC",
        "COD-FAMILIAR-FAM-EXC",
        "VAZIO",
        "NUM-REG-ARQUIVO",
        "DATA-EXC",
        "CPF-OPER-EXC",
        "MOTIVO-EXC",
        "NUM-PGMCU",
        "DAT-EMI-PGMCU",
        "NOM-SERVD-PBCO-PGMCU",
        "CPF-SERVD-PBCO-PGMCU-PGMCU",
        "UF-PGMCU",
        "MUN-PGMCU",
        "DESC-MOT-EXC",
    ]

    colspecs_18_access = [
        (1,   13),
        (14,  11),
        (25,  13),
        (38,   2),
        (40,   8),
        (48,  11),
        (59,   2),
        (61,  10),
        (71,   8),
        (79,  70),
        (149, 11),
        (160,  2),
        (162,  7),
        (169, 255),
    ]

    colspecs_18_pandas = [
        (inicio - 1, (inicio - 1) + largura)
        for inicio, largura in colspecs_18_access
    ]

    df_reg18 = pd.read_fwf(
        "/lakehouse/default/Files/bronze_cad_unico/bloco_18.txt",
        colspecs=colspecs_18_pandas,
        names=colnames_18,
        encoding="cp850",
        dtype=dtypes_cols_reg18,
    )

    df_reg18.columns = df_reg18.columns.str.lower().str.replace("-", "_")
    return df_reg18


def aplicar_dicionarios(df):
    cod_sexo_pessoa = {"1": "Masculino", "2": "Feminino"}
    cod_parentesco_rf_pessoa = {
        "01": "Pessoa responsável pela Unidade Familiar - RF",
        "02": "Cônjuge ou companheiro(a)",
        "03": "Filho(a)",
        "04": "Enteado(a)",
        "05": "Neto(a) ou bisneto(a)",
        "06": "Pai ou mãe",
        "07": "Sogro(a)",
        "08": "Irmão ou irmã",
        "09": "Genro ou nora",
        "10": "Outro parente",
        "11": "Não parente",
    }
    cod_deficiencia_memb = {"1": "Sim", "2": "Não"}
    cod_concluiu_frequentou_memb = {"1": "Sim", "2": "Não"}
    cod_sabe_ler_escrever_memb = {"1": "Sim", "2": "Não"}

    for col in [
        "cod_sexo_pessoa",
        "cod_parentesco_rf_pessoa",
        "cod_deficiencia_memb",
        "cod_concluiu_frequentou_memb",
        "cod_sabe_ler_escrever_memb",
    ]:
        if col in df.columns:
            df[col] = df[col].astype(str).str.replace(".0", "")

    if "cod_sexo_pessoa" in df.columns:
        df["desc_cod_sexo_pessoa"] = df["cod_sexo_pessoa"].map(cod_sexo_pessoa)
    if "cod_parentesco_rf_pessoa" in df.columns:
        df["desc_cod_parentesco_rf_pessoa"] = df["cod_parentesco_rf_pessoa"].map(cod_parentesco_rf_pessoa)
    if "cod_deficiencia_memb" in df.columns:
        df["desc_cod_deficiencia_memb"] = df["cod_deficiencia_memb"].map(cod_deficiencia_memb)
    if "cod_sabe_ler_escrever_memb" in df.columns:
        df["desc_cod_sabe_ler_escrever_memb"] = df["cod_sabe_ler_escrever_memb"].map(cod_sabe_ler_escrever_memb)
    if "cod_concluiu_frequentou_memb" in df.columns:
        df["desc_cod_concluiu_frequentou_memb"] = df["cod_concluiu_frequentou_memb"].map(cod_concluiu_frequentou_memb)
    return df


processar_txt_cadunico()

df_reg01 = ler_bloco_01()
df_reg02 = ler_bloco_02()
df_reg03 = ler_bloco_03()
df_reg04 = ler_bloco_04()
df_reg05 = ler_bloco_05()
df_reg06 = ler_bloco_06()
df_reg07 = ler_bloco_07()
df_reg09 = ler_bloco_09()
df_reg14 = ler_bloco_14()
df_reg16 = ler_bloco_16()
df_reg17 = ler_bloco_17()
df_reg18 = ler_bloco_18()


df_reg01 = df_reg01.drop(columns=["vazio", "filler"])
df_reg02 = df_reg02.drop(columns="vazio")
df_reg03 = df_reg03.drop(columns=["vazio", "vazio2"])
df_reg04 = df_reg04.drop(columns=["vazio", "vazio2"])
df_reg05 = df_reg05.drop(columns=['vazio', 'vazio2', 'vazio3'])
df_reg06 = df_reg06.drop(columns="vazio")
df_reg07 = df_reg07.drop(columns="vazio")
df_reg09 = df_reg09.drop(columns="vazio")
df_reg14 = df_reg14.drop(columns="vazio")
df_reg16 = df_reg16.drop(columns="vazio")
df_reg17 = df_reg17.drop(columns=['vazio', 'vazio2', 'vazio3'])
df_reg18 = df_reg18.drop(columns="vazio")

df_reg01['versao_arquivo'] = VERSAO
df_reg02['versao_arquivo'] = VERSAO
df_reg03['versao_arquivo'] = VERSAO
df_reg04['versao_arquivo'] = VERSAO
df_reg05['versao_arquivo'] = VERSAO
df_reg06['versao_arquivo'] = VERSAO
df_reg07['versao_arquivo'] = VERSAO
df_reg09['versao_arquivo'] = VERSAO
df_reg14['versao_arquivo'] = VERSAO
df_reg16['versao_arquivo'] = VERSAO
df_reg17['versao_arquivo'] = VERSAO
df_reg18['versao_arquivo'] = VERSAO
# Out:
# StatementMeta(, 9d332cb1-3b9a-4bc2-8c41-3cbe5851761f, 3, Finished, Available, Finished, False)

# %%
from pyspark.sql.types import StructType, StructField, StringType

registros = {
    "01": df_reg01,
    "02": df_reg02,
    "03": df_reg03,
    "04": df_reg04,
    "05": df_reg05,
    "06": df_reg06,
    "07": df_reg07,
    "09": df_reg09,
    "14": df_reg14,
    "16": df_reg16,
    "17": df_reg17,
    "18": df_reg18
}

for sufixo, df_pandas in registros.items():
    print(f"Processando registro {sufixo}...")

    nome_tabela = f"bronze_cad_unico_reg{sufixo}"

    # Converte tudo para string explicitamente
    df_str = df_pandas.astype(str).where(df_pandas.notna(), None)

    schema = StructType([StructField(col, StringType(), True) for col in df_str.columns])
    sdf = spark.createDataFrame(df_str, schema=schema)

    sdf.write.mode("append").format("delta").option("overwriteSchema", "true").saveAsTable(nome_tabela)
# Out:
# StatementMeta(, 9d332cb1-3b9a-4bc2-8c41-3cbe5851761f, 4, Finished, Available, Finished, False)
# Processando registro 01...
# Processando registro 02...
# Processando registro 03...
# Processando registro 04...
# Processando registro 05...
# Processando registro 06...
# Processando registro 07...
# Processando registro 09...
# Processando registro 14...
# Processando registro 16...
# Processando registro 17...
# Processando registro 18...
