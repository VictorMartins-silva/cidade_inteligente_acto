# %%
# %run ./config_api_acto
# Out:
# StatementMeta(, 77cf78aa-31fb-4b39-98c5-ebc2c9c2453e, 3, Finished, Available, Finished, True)

# %%
# %run ./nb_utils_maua_ingest_acto_gestao
# Out:
# StatementMeta(, 77cf78aa-31fb-4b39-98c5-ebc2c9c2453e, 4, Finished, Available, Finished, True)

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------

# %%
TOKEN = TOKEN_MAUA

base_path = "/lakehouse/default/Files/payload/"

# 0. TELA DE DEFERIDAS/INDEFERIDAS > COLUNA (DESISÕES)
payload_path0 = base_path + "payload_maua_deferimento_plan_urbano.json"
df_solicitacoes0, df_etapas0 = extrair_tabela_acto_gestao(payload_path0, TOKEN)

# 1. 2° VIA DE HABITE-SE
payload_path1 = base_path + "payload_maua_2_via_de_habite_se.json"
df_solicitacoes1, df_etapas1 = extrair_tabela_acto_gestao(payload_path1, TOKEN)

# 2. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO DE CONSTRUÇÃO
payload_path2 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_de_construcao.json"
df_solicitacoes2, df_etapas2 = extrair_tabela_acto_gestao(payload_path2, TOKEN)

# 3. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO DE MOVIMENTAÇÃO DE TERRA
payload_path3 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_de_movimentacao_de_terra.json"
df_solicitacoes3, df_etapas3 = extrair_tabela_acto_gestao(payload_path3, TOKEN)

# 4. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO DE MURO DE ARRIMO
payload_path4 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_de_muro_de_arrimo.json"
df_solicitacoes4, df_etapas4 = extrair_tabela_acto_gestao(payload_path4, TOKEN)

# 5. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO DE RECONSTRUÇÃO
payload_path5 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_de_reconstrucao.json"
df_solicitacoes5, df_etapas5 = extrair_tabela_acto_gestao(payload_path5, TOKEN)

# 6. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO DE REFORMA COM ACRÉSCIMO DE ÁREA
payload_path6 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_de_reforma_com_acrescido_de_area.json"
df_solicitacoes6, df_etapas6 = extrair_tabela_acto_gestao(payload_path6, TOKEN)

# 7. ALVARÁ DE APROVAÇÃO DE PROJETO E EXECUÇÃO PARA DEMOLIÇÃO
payload_path7 = base_path + "payload_maua_alvara_de_aprovacao_de_projeto_e_execucao_para_demolicao.json"
df_solicitacoes7, df_etapas7 = extrair_tabela_acto_gestao(payload_path7, TOKEN)

# 8. ALVARÁ DE AUTORIZAÇÃO
payload_path8 = base_path + "payload_maua_alvara_de_autorizacao.json"
df_solicitacoes8, df_etapas8 = extrair_tabela_acto_gestao(payload_path8, TOKEN)

# 9. ALVARÁ DE CONSERVAÇÃO - CONSERVAÇÃO DE EDIFICAÇÃO
payload_path9 = base_path + "payload_maua_alvara_de_conservacao_conservacao_de_edificacao.json"
df_solicitacoes9, df_etapas9 = extrair_tabela_acto_gestao(payload_path9, TOKEN)

# 10. AUTORIZAÇÃO DE FUNCIONAMENTO - LEI MUNICIPAL 6.181/2023
payload_path10 = base_path + "payload_maua_autorizacao_de_funcionamento_lei_municipal_6_181_2023.json"
df_solicitacoes10, df_etapas10 = extrair_tabela_acto_gestao(payload_path10, TOKEN)

# 11. CADASTRO GERAL DE DOCUMENTOS
payload_path11 = base_path + "payload_maua_cadastro_geral_de_documentos.json"
df_solicitacoes11, df_etapas11 = extrair_tabela_acto_gestao(payload_path11, TOKEN)

# 12. CERTIDÃO DE MEDIDAS E CONFRONTAÇÕES
payload_path12 = base_path + "payload_maua_certidao_de_medidas_e_confrontacoes.json"
df_solicitacoes12, df_etapas12 = extrair_tabela_acto_gestao(payload_path12, TOKEN)

# 13. CERTIDÃO DE NUMERAÇÃO E/OU ENDEREÇO OFICIAL
payload_path13 = base_path + "payload_maua_certidao_de_numeracao_e_ou_endereco_oficial.json"
df_solicitacoes13, df_etapas13 = extrair_tabela_acto_gestao(payload_path13, TOKEN)

# 14. CERTIDÃO DE USO DO SOLO (NOVO)
payload_path14 = base_path + "payload_maua_certidao_de_uso_do_solo_novo.json"
df_solicitacoes14, df_etapas14 = extrair_tabela_acto_gestao(payload_path14, TOKEN)

# 15. CERTIDÃO INFORMATIVA
payload_path15 = base_path + "payload_maua_certidao_informativa.json"
df_solicitacoes15, df_etapas15 = extrair_tabela_acto_gestao(payload_path15, TOKEN)

# 16. CERTIFICADO DE CONCLUSÃO
payload_path16 = base_path + "payload_maua_certificado_de_conclusao.json"
df_solicitacoes16, df_etapas16 = extrair_tabela_acto_gestao(payload_path16, TOKEN)

# 17. COMUNICAÇÃO DE OBRAS EMERGENCIAIS
payload_path17 = base_path + "payload_maua_comunicacao_de_obras_emergenciais.json"
df_solicitacoes17, df_etapas17 = extrair_tabela_acto_gestao(payload_path17, TOKEN)

# 18. COMUNICAÇÃO DE REFORMA SEM ACRÉSCIMO DE ÁREA
payload_path18 = base_path + "payload_maua_comunicacao_de_reforma_sem_acrescimo_de_area.json"
df_solicitacoes18, df_etapas18 = extrair_tabela_acto_gestao(payload_path18, TOKEN)

# 19. COMUNICAÇÃO DE REPAROS EM FACHADAS NO ALINHAMENTO
payload_path19 = base_path + "payload_maua_comunicacao_de_reparos_em_fachadas_no_alinhamento.json"
df_solicitacoes19, df_etapas19 = extrair_tabela_acto_gestao(payload_path19, TOKEN)

# 20. DESDOBRO, ENGLOBAMENTO E DESMEMBRAMENTO
payload_path20 = base_path + "payload_maua_desdobro_englobamento_e_desmembramento.json"
df_solicitacoes20, df_etapas20 = extrair_tabela_acto_gestao(payload_path20, TOKEN)

# 21. HABITE-SE
payload_path21 = base_path + "payload_maua_habite_se.json"
df_solicitacoes21, df_etapas21 = extrair_tabela_acto_gestao(payload_path21, TOKEN)

# 22. PRORROGAÇÃO DE ALVARÁ
payload_path22 = base_path + "payload_maua_prorrogacao_de_alvara.json"
df_solicitacoes22, df_etapas22 = extrair_tabela_acto_gestao(payload_path22, TOKEN)

# 23. REGULARIZAÇÃO PELA LEI MUNICIPAL 6.207/2024
payload_path23 = base_path + "payload_maua_regularizacao_pela_lei_municipal_6_207_2024.json"
df_solicitacoes23, df_etapas23 = extrair_tabela_acto_gestao(payload_path23, TOKEN)

# 24. SUBSTITUIÇÃO DE PROJETO APROVADO
payload_path24 = base_path + "payload_maua_substituicao_de_projeto_aprovado.json"
df_solicitacoes24, df_etapas24 = extrair_tabela_acto_gestao(payload_path24, TOKEN)

# 25. TRANSFERÊNCIA, BAIXA E ASSUNÇÃO DE RESPONSABILIDADE TÉCNICA
payload_path25 = base_path + "payload_maua_transferencia_baixa_e_assuncao_de_responsabilidade_tecnica.json"
df_solicitacoes25, df_etapas25 = extrair_tabela_acto_gestao(payload_path25, TOKEN)
# Out:
# Sucesso: /lakehouse/default/Files/payload/payload_maua_alvara_de_autorizacao.json | Solicitacoes: 16 | Etapas: 32
# Sucesso: /lakehouse/default/Files/payload/payload_maua_alvara_de_conservacao_conservacao_de_edificacao.json | Solicitacoes: 76 | Etapas: 1041
# Sucesso: /lakehouse/default/Files/payload/payload_maua_autorizacao_de_funcionamento_lei_municipal_6_181_2023.json | Solicitacoes: 477 | Etapas: 2712
# Sucesso: /lakehouse/default/Files/payload/payload_maua_cadastro_geral_de_documentos.json | Solicitacoes: 812 | Etapas: 805
# Sucesso: /lakehouse/default/Files/payload/payload_maua_certidao_de_medidas_e_confrontacoes.json | Solicitacoes: 1419 | Etapas: 9630
# Sucesso: /lakehouse/default/Files/payload/payload_maua_certidao_de_numeracao_e_ou_endereco_oficial.json | Solicitacoes: 632 | Etapas: 3453
# Sucesso: /lakehouse/default/Files/payload/payload_maua_certidao_de_uso_do_solo_novo.json | Solicitacoes: 466 | Etapas: 3294
# ...

# %%
base_save_path = "/lakehouse/default/Files/silver_planejamento_urbano/"

# =========================
# DECISÕES (deferido/indeferido) – payload 0
# =========================
colunas_decisao = [c for c in df_solicitacoes0.columns if c != "Nº Solicitação|1"]
df_decisoes = df_solicitacoes0.copy()
df_decisoes["Decisão"] = df_solicitacoes0[colunas_decisao].bfill(axis=1).iloc[:, 0]
df_decisoes = df_decisoes[["Nº Solicitação|1", "Decisão"]]
df_decisoes.to_parquet(base_save_path + "silver_decisoes_plan_urbano.parquet", index=False)

# =========================
# SOLICITAÇÕES
# =========================
df_solicitacoes0.to_parquet(base_save_path + "silver_solicitacoes_maua0.parquet", index=False)
df_solicitacoes1.to_parquet(base_save_path + "silver_solicitacoes_maua1.parquet", index=False)
df_solicitacoes2.to_parquet(base_save_path + "silver_solicitacoes_maua2.parquet", index=False)
df_solicitacoes3.to_parquet(base_save_path + "silver_solicitacoes_maua3.parquet", index=False)
df_solicitacoes4.to_parquet(base_save_path + "silver_solicitacoes_maua4.parquet", index=False)
df_solicitacoes5.to_parquet(base_save_path + "silver_solicitacoes_maua5.parquet", index=False)
df_solicitacoes6.to_parquet(base_save_path + "silver_solicitacoes_maua6.parquet", index=False)
df_solicitacoes7.to_parquet(base_save_path + "silver_solicitacoes_maua7.parquet", index=False)
df_solicitacoes8.to_parquet(base_save_path + "silver_solicitacoes_maua8.parquet", index=False)
df_solicitacoes9.to_parquet(base_save_path + "silver_solicitacoes_maua9.parquet", index=False)
df_solicitacoes10.to_parquet(base_save_path + "silver_solicitacoes_maua10.parquet", index=False)
df_solicitacoes11.to_parquet(base_save_path + "silver_solicitacoes_maua11.parquet", index=False)
df_solicitacoes12.to_parquet(base_save_path + "silver_solicitacoes_maua12.parquet", index=False)
df_solicitacoes13.to_parquet(base_save_path + "silver_solicitacoes_maua13.parquet", index=False)
df_solicitacoes14.to_parquet(base_save_path + "silver_solicitacoes_maua14.parquet", index=False)
df_solicitacoes15.to_parquet(base_save_path + "silver_solicitacoes_maua15.parquet", index=False)
df_solicitacoes16.to_parquet(base_save_path + "silver_solicitacoes_maua16.parquet", index=False)
df_solicitacoes17.to_parquet(base_save_path + "silver_solicitacoes_maua17.parquet", index=False)
df_solicitacoes18.to_parquet(base_save_path + "silver_solicitacoes_maua18.parquet", index=False)
df_solicitacoes19.to_parquet(base_save_path + "silver_solicitacoes_maua19.parquet", index=False)
df_solicitacoes20.to_parquet(base_save_path + "silver_solicitacoes_maua20.parquet", index=False)
df_solicitacoes21.to_parquet(base_save_path + "silver_solicitacoes_maua21.parquet", index=False)
df_solicitacoes22.to_parquet(base_save_path + "silver_solicitacoes_maua22.parquet", index=False)
df_solicitacoes23.to_parquet(base_save_path + "silver_solicitacoes_maua23.parquet", index=False)
df_solicitacoes24.to_parquet(base_save_path + "silver_solicitacoes_maua24.parquet", index=False)
df_solicitacoes25.to_parquet(base_save_path + "silver_solicitacoes_maua25.parquet", index=False)


# =========================
# ETAPAS
# =========================
lista_dfs = [globals()[f'df_etapas{i}'] for i in range(26)]
df_etapas = pd.concat(lista_dfs, axis=0)
df_etapas.to_parquet(base_save_path + "silver_maua_pl_urbano_etapas.parquet", index=False)

print("✓ Todas as tabelas silver de Mauá foram salvas com sucesso.")
# Out:
# StatementMeta(, 77cf78aa-31fb-4b39-98c5-ebc2c9c2453e, 21, Finished, Available, Finished, False)
# ✓ Todas as tabelas silver de Mauá foram salvas com sucesso.
